# %%
# poc multivariate linear regression 
# code from https://datatofish.com/multiple-linear-regression-python/

import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm

gba_market = {
    'Year': [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],
    'Population': [4402.611,4443.310,4459.011,4458.187,4456.479,4458.891,4473.477,4503.921,4544.705,4588.680,4566.348,4609.790,4656.593,4702.877,4746.931,4778.340,4809.061,4841.772,4859.536],
    'Income': [40641,39621,39993,40089,41517,43155,47312,49853,51145,53751,49584,49033,50884,54164,54280,56530,61367,65999,68743],
    'Price':[101.049723660094,119.307068109226,126.966248896496,140.587574712244,150.298194567724,162.888413989627,165.976741236016,157.382204882058,157.372824690462,149.420163254923,149.71379253986,
             150.474041294607,147.323854315729,151.186685110972,164.602052803123,171.26626662146,175.665395214037,183.330302586662,191.331293384609]
}

df = pd.DataFrame(gba_market, columns=['Year','Population','Income','Price'])

X = df[['Population','Income']]
Y = df['Price']

# with sklearn
reg = linear_model.LinearRegression()
reg.fit(X,Y)

print('Int: ', reg.intercept_)
print('Coef: ', reg.coef_)

# with statsmodels
X = sm.add_constant(X) # not sure what add_constant does but apparently is important to accuracy of model
model = sm.OLS(Y,X).fit()
predictions = model.predict(X)

print_model = model.summary()
print(print_model)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Int:  115.48598973004097
# Coef:  [-0.01716264  0.00231945]
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     16.07
# Date:                Mon, 14 Dec 2020   Prob (F-statistic):           0.000149
# Time:                        01:43:49   Log-Likelihood:                -74.375
# No. Observations:                  19   AIC:                             154.7
# Df Residuals:                      16   BIC:                             157.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

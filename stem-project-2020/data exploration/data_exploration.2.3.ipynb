# %% [markdown]
# # GDP

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv('/content/summarized data.xlsx - 工作表2.3.csv')
df_train['House_Price_Index'].describe()
# Out:
# count    205.000000
# mean     166.328174
# std       19.788366
# min      118.201625
# 25%      153.733975
# 50%      165.853192
# 75%      180.044039
# max      212.737331
# Name: House_Price_Index, dtype: float64

# %%
var = 'GDP'
data = pd.concat([df_train['House_Price_Index'],df_train[var]],axis=1)
data.plot.scatter(x=var,y='House_Price_Index')

# %% [markdown]
# # CPI

# %%
# CPI
var = 'CPI'
data = pd.concat([df_train['House_Price_Index'],df_train[var]],axis=1)
data.plot.scatter(x=var,y='House_Price_Index')

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.2.0

# %%
raw_dataset = pd.read_csv('Dallas data summary Interpolated.csv',
                      na_values = "?", comment='\t',
                      sep=",", skipinitialspace=True)

features = raw_dataset.copy()

features.tail(20)
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 146   5/1/2017                            176.53401                     4.01
# 147   6/1/2017                            177.85815                     3.90
# 148   7/1/2017                            178.50937                     3.97
# 149   8/1/2017                            179.03170                     3.88
# 150   9/1/2017                            179.73311                     3.81
# 151  10/1/2017                            180.42716                     3.90
# 152  11/1/2017                            180.64196                     3.92
# 153  12/1/2017                            180.78713                     3.95
# 154   1/1/2018                            181.23406                     4.03
# 155   2/1/2018                            182.28582                     4.33
# 156   3/1/2018                            183.58835                     4.44
# 157   4/1/2018                            185.27276                     4.47
# 158   5/1/2018                            186.42279                     4.59
# 159   6/1/2018                            187.15900                     4.57
# 160   7/1/2018                            187.50014                     4.53
# 161   8/1/2018                            187.43342                     4.55
# 162   9/1/2018                            187.42928                     4.63
# 163  10/1/2018                            187.49068                     4.83
# 164  11/1/2018                            187.88942                     4.87
# 165  12/1/2018                            187.97905                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 146      54868.00000          7376.650000                3.6  487373.6517
# 147      55117.50000          7386.538250                3.9  489673.0096
# 148      55367.00000          7396.426500                3.9  491972.3675
# 149      55616.50000          7406.314750                3.9  494271.7254
# 150      55866.00000          7416.203000                3.5  496571.0833
# 151      56115.50000          7426.091250                3.3  498870.4413
# 152      56365.00000          7435.979500                3.4  501169.7992
# 153      56614.50000          7445.867750                3.3  503469.1571
# 154      56864.00000          7455.756000                3.7  505768.5150
# 155      57019.08333          7465.537667                3.7  507276.3032
# 156      57174.16667          7475.319333                3.6  508784.0913
# 157      57329.25000          7485.101000                3.3  510291.8795
# 158      57484.33333          7494.882667                3.3  511799.6677
# 159      57639.41667          7504.664333                3.9  513307.4558
# 160      57794.50000          7514.446000                3.7  514815.2440
# 161      57949.58333          7524.227667                3.6  516323.0322
# 162      58104.66667          7534.009333                3.4  517830.8203
# 163      58259.75000          7543.791000                3.3  519338.6085
# 164      58414.83333          7553.572667                3.2  520846.3967
# 165      58569.91667          7563.354333                3.3  522354.1848
#
#      Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 146  767.508617                     35.17%  140028.3333
# 147  768.527900                     35.10%  140633.0000
# 148  769.547183                     34.97%  141250.6667
# 149  770.566467                     34.83%  141868.3333
# 150  771.585750                     34.70%  142486.0000
# 151  772.605033                     34.63%  143060.0000
# 152  773.624317                     34.57%  143634.0000
# 153  774.643600                     34.50%  144208.0000
# 154  773.834725                     34.57%  144725.6667
# 155  773.025850                     34.63%  145243.3333
# 156  772.216975                     34.70%  145761.0000
# 157  771.408100                     34.63%  146290.3333
# 158  770.599225                     34.57%  146819.6667
# 159  769.790350                     34.50%  147349.0000
# 160  768.981475                     34.47%  148290.6667
# 161  768.172600                     34.43%  149232.3333
# 162  767.363725                     34.40%  150174.0000
# 163  766.554850                     34.27%  150611.3333
# 164  765.745975                     34.13%  151048.6667
# 165  764.937100                     34.00%  151486.0000
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 146                                 1.27%            4995
# 147                                 1.20%            5659
# 148                                 1.20%            4250
# 149                                 1.20%            6620
# 150                                 1.20%            4446
# 151                                 1.27%            6459
# 152                                 1.33%            3754
# 153                                 1.40%            3631
# 154                                 1.37%            5687
# 155                                 1.33%            3979
# 156                                 1.30%            4814
# 157                                 1.23%            8213
# 158                                 1.17%            4805
# 159                                 1.10%            5813
# 160                                 1.10%            5275
# 161                                 1.10%            5416
# 162                                 1.10%            4336
# 163                                 1.10%            4505
# 164                                 1.10%            4920
# 165                                 1.10%            4099
#
#      Economic_Conditions_Index  CPI all items less shelter
# 146                       3.77                  222.749667
# 147                       3.94                  223.125083
# 148                       3.76                  223.500500
# 149                       3.91                  223.875917
# 150                       4.15                  224.251333
# 151                       4.03                  224.626750
# 152                       3.73                  225.002167
# 153                       3.54                  225.377583
# 154                       3.46                  225.753000
# 155                       3.59                  226.013667
# 156                       3.72                  226.274333
# 157                       3.81                  226.535000
# 158                       4.16                  226.795667
# 159                       4.25                  227.056333
# 160                       4.22                  227.317000
# 161                       4.18                  227.577667
# 162                       4.02                  227.838333
# 163                       4.09                  228.099000
# 164                       4.05                  228.359667
# 165                       3.93                  228.620333

# %%
mort_debt = np.array(features['Percent_With_Mortgage_Debt'])
mdebt = []
for x in mort_debt:
  mdebt.append(float(x[:5]))
features = features.drop('Percent_With_Mortgage_Debt',axis=1)

del_debt = np.array(features['Percent_With_Severely_Delinquent_Debt'])
ddebt = []
for x in del_debt:
  ddebt.append(float(x[:4]))
features = features.drop('Percent_With_Severely_Delinquent_Debt',axis=1)

features['Percent_With_Mortgage_Debt'] = mdebt
features['Percent_With_Severely_Delinquent_Debt'] = ddebt
features.head()
# Out:
#        Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0  3/1/2005                            117.37315                     5.93
# 1  4/1/2005                            118.36502                     5.86
# 2  5/1/2005                            119.47166                     5.72
# 3  6/1/2005                            120.02775                     5.58
# 4  7/1/2005                            120.82903                     5.70
#
#    Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0          37170.0            5816.4070                5.3  284456.5080
# 1          37443.3            5834.7074                5.1  286767.0694
# 2          37716.6            5853.0078                5.1  289077.6308
# 3          37989.9            5871.3082                5.4  291388.1922
# 4          38263.2            5889.6086                5.4  293698.7536
#
#    Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0   1309.5483  133706.0000            4281                       4.19
# 1   1303.3853  133866.0000            5548                       4.69
# 2   1297.2223  134026.0000            4878                       4.58
# 3   1291.0593  134186.0000            5304                       4.83
# 4   1284.8963  134134.6667            5140                       5.06
#
#    CPI all items less shelter  Percent_With_Mortgage_Debt  \
# 0                      188.90                       43.20
# 1                      189.67                       43.27
# 2                      190.44                       43.33
# 3                      191.21                       43.40
# 4                      191.98                       43.40
#
#    Percent_With_Severely_Delinquent_Debt
# 0                                    2.3
# 1                                    2.3
# 2                                    2.3
# 3                                    2.3
# 4                                    2.3

# %%
features.isna().sum()
# Out:
# Date                                     0
# House_Price_Index(S&P/Case-Shiller)      0
# Mortgage_Rate (30 yers)                  0
# Personal_Income                          0
# Resident_Population                      0
# Unemployment_Rate                        0
# GDP                                      0
# Crime_Rate                               0
# Median_Debt                              0
# New_Structures                           0
# Economic_Conditions_Index                0
# CPI all items less shelter               0
# Percent_With_Mortgage_Debt               0
# Percent_With_Severely_Delinquent_Debt    0
# dtype: int64

# %%
features=features.drop('Date',axis=1)
train_dataset = features.iloc[:154]
test_dataset = features.iloc[154:]

# %%
train_dataset
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                              117.37315                     5.93
# 1                              118.36502                     5.86
# 2                              119.47166                     5.72
# 3                              120.02775                     5.58
# 4                              120.82903                     5.70
# ..                                   ...                      ...
# 149                            179.03170                     3.88
# 150                            179.73311                     3.81
# 151                            180.42716                     3.90
# 152                            180.64196                     3.92
# 153                            180.78713                     3.95
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0            37170.0           5816.40700                5.3  284456.5080
# 1            37443.3           5834.70740                5.1  286767.0694
# 2            37716.6           5853.00780                5.1  289077.6308
# 3            37989.9           5871.30820                5.4  291388.1922
# 4            38263.2           5889.60860                5.4  293698.7536
# ..               ...                  ...                ...          ...
# 149          55616.5           7406.31475                3.9  494271.7254
# 150          55866.0           7416.20300                3.5  496571.0833
# 151          56115.5           7426.09125                3.3  498870.4413
# 152          56365.0           7435.97950                3.4  501169.7992
# 153          56614.5           7445.86775                3.3  503469.1571
#
#       Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    1309.548300  133706.0000            4281                       4.19
# 1    1303.385300  133866.0000            5548                       4.69
# 2    1297.222300  134026.0000            4878                       4.58
# 3    1291.059300  134186.0000            5304                       4.83
# 4    1284.896300  134134.6667            5140                       5.06
# ..           ...          ...             ...                        ...
# 149   770.566467  141868.3333            6620                       3.91
# 150   771.585750  142486.0000            4446                       4.15
# 151   772.605033  143060.0000            6459                       4.03
# 152   773.624317  143634.0000            3754                       3.73
# 153   774.643600  144208.0000            3631                       3.54
#
#      CPI all items less shelter  Percent_With_Mortgage_Debt  \
# 0                    188.900000                       43.20
# 1                    189.670000                       43.27
# 2                    190.440000                       43.33
# 3                    191.210000                       43.40
# 4                    191.980000                       43.40
# ..                          ...                         ...
# 149                  223.875917                       34.83
# 150                  224.251333                       34.70
# 151                  224.626750                       34.63
# 152                  225.002167                       34.57
# 153                  225.377583                       34.50
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                     2.30
# 1                                     2.30
# 2                                     2.30
# 3                                     2.30
# 4                                     2.30
# ..                                     ...
# 149                                   1.20
# 150                                   1.20
# 151                                   1.27
# 152                                   1.33
# 153                                   1.40
#
# [154 rows x 13 columns]

# %%
train_stats = train_dataset.describe()
train_stats.pop('House_Price_Index(S&P/Case-Shiller)')
train_stats = train_stats.transpose()
train_stats
# Out:
#                                        count           mean           std  \
# Mortgage_Rate (30 yers)                154.0       4.769286      1.037777
# Personal_Income                        154.0   45938.311688   5140.283086
# Resident_Population                    154.0    6643.101334    438.076717
# Unemployment_Rate                      154.0       5.522078      1.552070
# GDP                                    154.0  380112.103103  59440.837770
# Crime_Rate                             154.0     846.791258    213.924261
# Median_Debt                            154.0  133522.149351   3829.751495
# New_Structures                         154.0    3387.207792   1389.015967
# Economic_Conditions_Index              154.0       3.324026      2.089403
# CPI all items less shelter             154.0     213.928282     10.028485
# Percent_With_Mortgage_Debt             154.0      40.396753      3.155776
# Percent_With_Severely_Delinquent_Debt  154.0       2.835714      0.983563
#
#                                                min            25%  \
# Mortgage_Rate (30 yers)                     3.3500       3.912500
# Personal_Income                         37170.0000   41208.437500
# Resident_Population                      5816.4070    6352.981042
# Unemployment_Rate                           3.3000       4.100000
# GDP                                    284456.5080  331357.882050
# Crime_Rate                                663.7371     679.451525
# Median_Debt                            127063.0000  130323.500025
# New_Structures                           1098.0000    2245.750000
# Economic_Conditions_Index                  -4.4600       3.530000
# CPI all items less shelter                188.9000     207.413062
# Percent_With_Mortgage_Debt                 34.5000      37.425000
# Percent_With_Severely_Delinquent_Debt       1.2000       2.300000
#
#                                                  50%            75%  \
# Mortgage_Rate (30 yers)                     4.430000       5.850000
# Personal_Income                         45839.166665   50452.250000
# Resident_Population                      6583.135458    7001.183479
# Unemployment_Rate                           5.150000       6.775000
# GDP                                    365689.391650  430273.328675
# Crime_Rate                                752.616733     992.892338
# Median_Debt                            134240.500000  136127.499975
# New_Structures                           3325.500000    4372.250000
# Economic_Conditions_Index                   4.010000       4.405000
# CPI all items less shelter                219.690250     221.930729
# Percent_With_Mortgage_Debt                 41.850000      43.200000
# Percent_With_Severely_Delinquent_Debt       2.615000       3.792500
#
#                                                  max
# Mortgage_Rate (30 yers)                     6.760000
# Personal_Income                         56614.500000
# Resident_Population                      7445.867750
# Unemployment_Rate                           8.700000
# GDP                                    503469.157100
# Crime_Rate                               1309.548300
# Median_Debt                            144208.000000
# New_Structures                           7374.000000
# Economic_Conditions_Index                   5.220000
# CPI all items less shelter                225.377583
# Percent_With_Mortgage_Debt                 44.100000
# Percent_With_Severely_Delinquent_Debt       4.800000

# %%
train_labels = train_dataset.pop('House_Price_Index(S&P/Case-Shiller)')
test_labels = test_dataset.pop('House_Price_Index(S&P/Case-Shiller)')

# %%
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
normed_train_data.head(20)
# Out:
#     Mortgage_Rate (30 yers)  Personal_Income  Resident_Population  \
# 0                  1.118462        -1.705803            -1.887099
# 1                  1.051011        -1.652635            -1.845325
# 2                  0.916107        -1.599467            -1.803551
# 3                  0.781203        -1.546298            -1.761776
# 4                  0.896835        -1.493130            -1.720002
# 5                  1.012467        -1.439962            -1.678227
# 6                  0.964287        -1.386794            -1.636453
# 7                  1.253366        -1.333625            -1.594679
# 8                  1.503902        -1.280457            -1.552904
# 9                  1.446086        -1.227289            -1.511130
# 10                 1.330454        -1.174120            -1.469355
# 11                 1.426814        -1.151165            -1.439444
# 12                 1.494266        -1.128209            -1.409533
# 13                 1.677350        -1.105253            -1.379622
# 14                 1.764073        -1.082297            -1.349710
# 15                 1.841161        -1.059341            -1.319799
# 16                 1.918249        -1.036385            -1.289888
# 17                 1.686985        -1.013429            -1.259977
# 18                 1.571354        -0.990473            -1.230065
# 19                 1.532810        -0.967517            -1.200154
#
#     Unemployment_Rate       GDP  Crime_Rate  Median_Debt  New_Structures  \
# 0           -0.143085 -1.609257    2.163182     0.048006        0.643472
# 1           -0.271945 -1.570386    2.134372     0.089784        1.555628
# 2           -0.271945 -1.531514    2.105563     0.131562        1.073272
# 3           -0.078655 -1.492642    2.076754     0.173340        1.379964
# 4           -0.078655 -1.453771    2.047945     0.159937        1.261895
# 5           -0.207515 -1.414899    2.019135     0.146533        1.911276
# 6           -0.271945 -1.376027    1.990326     0.133129        0.701066
# 7           -0.465235 -1.337156    1.961517     0.177257        1.027196
# 8           -0.336375 -1.298284    1.932708     0.221385        0.954483
# 9           -0.465235 -1.259413    1.903898     0.265513        1.490834
# 10          -0.271945 -1.220541    1.885307     0.394591        0.537641
# 11          -0.271945 -1.193308    1.866715     0.523668        0.757941
# 12          -0.465235 -1.166076    1.848124     0.652745        1.899757
# 13          -0.529666 -1.138843    1.829532     0.551781        1.048074
# 14          -0.465235 -1.111611    1.810940     0.450817        1.385004
# 15          -0.207515 -1.084378    1.792349     0.349853        2.870228
# 16          -0.207515 -1.057146    1.773757     0.431146        1.166864
# 17          -0.465235 -1.029913    1.755166     0.512440        0.999119
# 18          -0.529666 -1.002681    1.736574     0.593733        0.582997
# 19          -0.787386 -0.975448    1.717982     0.739522        0.153196
#
#     Economic_Conditions_Index  CPI all items less shelter  \
# 0                    0.414460                   -2.495719
# 1                    0.653763                   -2.418938
# 2                    0.601116                   -2.342157
# 3                    0.720768                   -2.265375
# 4                    0.830847                   -2.188594
# 5                    0.495823                   -2.111813
# 6                    0.510181                   -2.035032
# 7                    0.538897                   -1.958250
# 8                    0.486251                   -1.881469
# 9                    0.476679                   -1.804688
# 10                   0.495823                   -1.727906
# 11                   0.409674                   -1.699969
# 12                   0.438390                   -1.672032
# 13                   0.471893                   -1.644095
# 14                   0.562828                   -1.616158
# 15                   0.548470                   -1.588221
# 16                   0.342669                   -1.560284
# 17                   0.543683                   -1.532347
# 18                   0.610688                   -1.504410
# 19                   0.505395                   -1.476473
#
#     Percent_With_Mortgage_Debt  Percent_With_Severely_Delinquent_Debt
# 0                     0.888291                              -0.544667
# 1                     0.910472                              -0.544667
# 2                     0.929485                              -0.544667
# 3                     0.951667                              -0.544667
# 4                     0.951667                              -0.544667
# 5                     0.951667                              -0.544667
# 6                     0.951667                              -0.544667
# 7                     0.929485                              -0.473497
# 8                     0.910472                              -0.412495
# 9                     0.888291                              -0.341325
# 10                    0.834421                              -0.412495
# 11                    0.783721                              -0.473497
# 12                    0.729851                              -0.544667
# 13                    0.729851                              -0.473497
# 14                    0.729851                              -0.412495
# 15                    0.729851                              -0.341325
# 16                    0.793227                              -0.412495
# 17                    0.856603                              -0.473497
# 18                    0.919979                              -0.544667
# 19                    0.834421                              -0.544667

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                832
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,057
# Trainable params: 5,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[-0.01062031],
#        [-0.04487145],
#        [-0.04051954],
#        [-0.11822069],
#        [-0.1052781 ],
#        [-0.0115068 ],
#        [-0.00522567],
#        [ 0.06006372],
#        [ 0.06694204],
#        [ 0.09373088]], dtype=float32)

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 400

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [pressure2]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,200])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [pressure2^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,40000])
  plt.legend()
  plt.show()


plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-132209ce9510> in <module>
#      25
#      26
# ---> 27 plot_history(history)
#
# <ipython-input-14-132209ce9510> in plot_history(history)
#       8   plt.plot(hist['epoch'], hist['mae'],
#       9            label='Train Error')
# ---> 10   plt.plot(hist['epoch'], hist['val_mae'],
#      11            label = 'Val Error')
#      12   plt.ylim([0,200])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'

# %%
test_predictions = model.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 250]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

test_errors = abs(test_predictions - test_labels)


print('Mean Absolute Error:', round(np.mean(test_errors), 2))

mape = np.mean(100 * (test_errors / test_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 3.89
# Accuracy: 97.92 %.

# %%
train_predictions = model.predict(normed_train_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(train_labels, train_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 220]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
train_errors = abs(train_predictions - train_labels)


print('Mean Absolute Error:', round(np.mean(train_errors), 2))

mape = np.mean(100 * (train_errors / train_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 1.59
# Accuracy: 98.76 %.

# %%
prediction_features=features   #produce prediction result
prediction_features
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                              117.37315                     5.93
# 1                              118.36502                     5.86
# 2                              119.47166                     5.72
# 3                              120.02775                     5.58
# 4                              120.82903                     5.70
# ..                                   ...                      ...
# 161                            187.43342                     4.55
# 162                            187.42928                     4.63
# 163                            187.49068                     4.83
# 164                            187.88942                     4.87
# 165                            187.97905                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0        37170.00000          5816.407000                5.3  284456.5080
# 1        37443.30000          5834.707400                5.1  286767.0694
# 2        37716.60000          5853.007800                5.1  289077.6308
# 3        37989.90000          5871.308200                5.4  291388.1922
# 4        38263.20000          5889.608600                5.4  293698.7536
# ..               ...                  ...                ...          ...
# 161      57949.58333          7524.227667                3.6  516323.0322
# 162      58104.66667          7534.009333                3.4  517830.8203
# 163      58259.75000          7543.791000                3.3  519338.6085
# 164      58414.83333          7553.572667                3.2  520846.3967
# 165      58569.91667          7563.354333                3.3  522354.1848
#
#       Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    1309.548300  133706.0000            4281                       4.19
# 1    1303.385300  133866.0000            5548                       4.69
# 2    1297.222300  134026.0000            4878                       4.58
# 3    1291.059300  134186.0000            5304                       4.83
# 4    1284.896300  134134.6667            5140                       5.06
# ..           ...          ...             ...                        ...
# 161   768.172600  149232.3333            5416                       4.18
# 162   767.363725  150174.0000            4336                       4.02
# 163   766.554850  150611.3333            4505                       4.09
# 164   765.745975  151048.6667            4920                       4.05
# 165   764.937100  151486.0000            4099                       3.93
#
#      CPI all items less shelter  Percent_With_Mortgage_Debt  \
# 0                    188.900000                       43.20
# 1                    189.670000                       43.27
# 2                    190.440000                       43.33
# 3                    191.210000                       43.40
# 4                    191.980000                       43.40
# ..                          ...                         ...
# 161                  227.577667                       34.43
# 162                  227.838333                       34.40
# 163                  228.099000                       34.27
# 164                  228.359667                       34.13
# 165                  228.620333                       34.00
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                      2.3
# 1                                      2.3
# 2                                      2.3
# 3                                      2.3
# 4                                      2.3
# ..                                     ...
# 161                                    1.1
# 162                                    1.1
# 163                                    1.1
# 164                                    1.1
# 165                                    1.1
#
# [166 rows x 13 columns]

# %%
prediction_features.pop('House_Price_Index(S&P/Case-Shiller)')
normed_prediction_features=norm(prediction_features)
prediction_result=model.predict(normed_prediction_features)
prediction_result=pd.DataFrame(prediction_result)
rawdataset=raw_dataset.join(prediction_result)
rawdataset
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0     3/1/2005                            117.37315                     5.93
# 1     4/1/2005                            118.36502                     5.86
# 2     5/1/2005                            119.47166                     5.72
# 3     6/1/2005                            120.02775                     5.58
# 4     7/1/2005                            120.82903                     5.70
# ..         ...                                  ...                      ...
# 161   8/1/2018                            187.43342                     4.55
# 162   9/1/2018                            187.42928                     4.63
# 163  10/1/2018                            187.49068                     4.83
# 164  11/1/2018                            187.88942                     4.87
# 165  12/1/2018                            187.97905                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0        37170.00000          5816.407000                5.3  284456.5080
# 1        37443.30000          5834.707400                5.1  286767.0694
# 2        37716.60000          5853.007800                5.1  289077.6308
# 3        37989.90000          5871.308200                5.4  291388.1922
# 4        38263.20000          5889.608600                5.4  293698.7536
# ..               ...                  ...                ...          ...
# 161      57949.58333          7524.227667                3.6  516323.0322
# 162      58104.66667          7534.009333                3.4  517830.8203
# 163      58259.75000          7543.791000                3.3  519338.6085
# 164      58414.83333          7553.572667                3.2  520846.3967
# 165      58569.91667          7563.354333                3.3  522354.1848
#
#       Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 0    1309.548300                     43.20%  133706.0000
# 1    1303.385300                     43.27%  133866.0000
# 2    1297.222300                     43.33%  134026.0000
# 3    1291.059300                     43.40%  134186.0000
# 4    1284.896300                     43.40%  134134.6667
# ..           ...                        ...          ...
# 161   768.172600                     34.43%  149232.3333
# 162   767.363725                     34.40%  150174.0000
# 163   766.554850                     34.27%  150611.3333
# 164   765.745975                     34.13%  151048.6667
# 165   764.937100                     34.00%  151486.0000
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 0                                   2.30%            4281
# 1                                   2.30%            5548
# 2                                   2.30%            4878
# 3                                   2.30%            5304
# 4                                   2.30%            5140
# ..                                    ...             ...
# 161                                 1.10%            5416
# 162                                 1.10%            4336
# 163                                 1.10%            4505
# 164                                 1.10%            4920
# 165                                 1.10%            4099
#
#      Economic_Conditions_Index  CPI all items less shelter           0
# 0                         4.19                  188.900000  120.238731
# 1                         4.69                  189.670000  121.227707
# 2                         4.58                  190.440000  119.383675
# 3                         4.83                  191.210000  117.941544
# 4                         5.06                  191.980000  117.323944
# ..                         ...                         ...         ...
# 161                       4.18                  227.577667  188.765793
# 162                       4.02                  227.838333  190.842117
# 163                       4.09                  228.099000  193.969559
# 164                       4.05                  228.359667  197.030991
# 165                       3.93                  228.620333  196.147385
#
# [166 rows x 15 columns]

# %%
rawdataset.to_csv('prediction-result.csv',index = False, header=True)

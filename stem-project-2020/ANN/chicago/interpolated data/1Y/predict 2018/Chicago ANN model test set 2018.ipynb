# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.2.0

# %%
raw_dataset = pd.read_csv('chicago data summary Interpolated(1Y).csv',
                      na_values = "?", comment='\t',
                      sep=",", skipinitialspace=True)

features = raw_dataset.copy()

features.tail(20)
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 146   5/1/2017                           141.847600                     4.01
# 147   6/1/2017                           141.817359                     3.90
# 148   7/1/2017                           141.861185                     3.97
# 149   8/1/2017                           142.383146                     3.88
# 150   9/1/2017                           143.084706                     3.81
# 151  10/1/2017                           143.920804                     3.90
# 152  11/1/2017                           144.291681                     3.92
# 153  12/1/2017                           144.192156                     3.95
# 154   1/1/2018                           144.104591                     4.03
# 155   2/1/2018                           144.268701                     4.33
# 156   3/1/2018                           143.900546                     4.44
# 157   4/1/2018                           144.165744                     4.47
# 158   5/1/2018                           144.124959                     4.59
# 159   6/1/2018                           144.387889                     4.57
# 160   7/1/2018                           144.432184                     4.53
# 161   8/1/2018                           144.422443                     4.55
# 162   9/1/2018                           143.719229                     4.63
# 163  10/1/2018                           144.269699                     4.83
# 164  11/1/2018                           144.419653                     4.87
# 165  12/1/2018                           145.127952                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 146      59434.66667          9504.128000                4.4  669518.1617
# 147      59710.58333          9501.631750                5.1  672239.4436
# 148      59986.50000          9499.135500                5.1  674960.7255
# 149      60262.41667          9496.639250                5.3  677682.0074
# 150      60538.33333          9494.143000                4.6  680403.2893
# 151      60814.25000          9491.646750                4.5  683124.5713
# 152      61090.16667          9489.150500                4.4  685845.8532
# 153      61366.08333          9486.654250                4.4  688567.1351
# 154      61642.00000          9484.158000                5.0  691288.4170
# 155      61796.83333          9482.023083                4.8  692777.7163
# 156      61951.66667          9479.888167                4.1  694267.0155
# 157      62106.50000          9477.753250                3.7  695756.3148
# 158      62261.33333          9475.618333                3.5  697245.6140
# 159      62416.16667          9473.483417                4.5  698734.9133
# 160      62571.00000          9471.348500                4.3  700224.2125
# 161      62725.83333          9469.213583                4.1  701713.5118
# 162      62880.66667          9467.078667                3.7  703202.8110
# 163      63035.50000          9464.943750                3.9  704692.1103
# 164      63190.33333          9462.808833                3.6  706181.4095
# 165      63345.16667          9460.673917                4.0  707670.7088
#
#       Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 146  1102.721667                     36.33%  164662.0000
# 147  1102.170000                     36.30%  164674.0000
# 148  1101.618333                     36.13%  164728.6667
# 149  1101.066667                     35.97%  164783.3333
# 150  1100.515000                     35.80%  164838.0000
# 151  1099.963333                     35.70%  164832.3333
# 152  1099.411667                     35.60%  164826.6667
# 153  1098.860000                     35.50%  164821.0000
# 154  1091.129167                     35.67%  164696.6667
# 155  1083.398333                     35.83%  164572.3333
# 156  1075.667500                     36.00%  164448.0000
# 157  1067.936667                     35.93%  164310.0000
# 158  1060.205833                     35.87%  164172.0000
# 159  1052.475000                     35.80%  164034.0000
# 160  1044.744167                     35.80%  164357.0000
# 161  1037.013333                     35.80%  164680.0000
# 162  1029.282500                     35.80%  165003.0000
# 163  1021.551667                     35.67%  165081.0000
# 164  1013.820833                     35.53%  165159.0000
# 165  1006.090000                     35.40%  165237.0000
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 146                                 1.87%            1201
# 147                                 1.80%            3207
# 148                                 1.80%            1140
# 149                                 1.80%            1785
# 150                                 1.80%            1810
# 151                                 1.80%            1895
# 152                                 1.80%            1499
# 153                                 1.80%            1699
# 154                                 1.77%             671
# 155                                 1.73%             864
# 156                                 1.70%            1370
# 157                                 1.63%            1767
# 158                                 1.57%            2161
# 159                                 1.50%            1688
# 160                                 1.47%            1282
# 161                                 1.43%            1615
# 162                                 1.40%            1583
# 163                                 1.40%            1736
# 164                                 1.40%            2011
# 165                                 1.40%            1064
#
#      Economic_Conditions_Index  CPI all items less shelter
# 146                       1.43                     209.999
# 147                       1.43                     209.434
# 148                       1.44                     210.359
# 149                       1.56                     211.010
# 150                       1.79                     211.699
# 151                       1.75                     210.498
# 152                       1.89                     211.096
# 153                       1.94                     210.373
# 154                       1.96                     211.957
# 155                       1.99                     211.617
# 156                       1.85                     211.577
# 157                       1.21                     213.099
# 158                       1.49                     213.764
# 159                       1.61                     212.952
# 160                       1.62                     212.395
# 161                       1.51                     212.840
# 162                       1.35                     213.605
# 163                       1.35                     213.241
# 164                       1.44                     211.004
# 165                       1.34                     209.956

# %%
mort_debt = np.array(features['Percent_With_Mortgage_Debt'])
mdebt = []
for x in mort_debt:
  mdebt.append(float(x[:5]))
features = features.drop('Percent_With_Mortgage_Debt',axis=1)

del_debt = np.array(features['Percent_With_Severely_Delinquent_Debt'])
ddebt = []
for x in del_debt:
  ddebt.append(float(x[:4]))
features = features.drop('Percent_With_Severely_Delinquent_Debt',axis=1)

features['Percent_With_Mortgage_Debt'] = mdebt
features['Percent_With_Severely_Delinquent_Debt'] = ddebt
features.head()
# Out:
#        Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0  3/1/2005                           168.016174                     5.93
# 1  4/1/2005                           167.616675                     5.86
# 2  5/1/2005                           167.717165                     5.72
# 3  6/1/2005                           167.155395                     5.58
# 4  7/1/2005                           166.556535                     5.70
#
#    Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0          40731.0            9362.0800                6.2  471401.4910
# 1          41006.9            9365.7575                6.1  473749.3002
# 2          41282.8            9369.4350                6.0  476097.1094
# 3          41558.7            9373.1125                6.4  478444.9186
# 4          41834.6            9376.7900                6.0  480792.7278
#
#    Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    1195.605  177440.0000            4629                       1.68
# 1    1195.605  177931.6667            4585                       2.00
# 2    1195.605  178423.3333            4618                       1.43
# 3    1195.605  178915.0000            4476                       1.44
# 4    1195.605  179127.6667            4920                       2.00
#
#    CPI all items less shelter  Percent_With_Mortgage_Debt  \
# 0                       175.2                       43.50
# 1                       177.3                       43.50
# 2                       176.9                       43.50
# 3                       177.0                       43.50
# 4                       177.3                       43.47
#
#    Percent_With_Severely_Delinquent_Debt
# 0                                   1.70
# 1                                   1.67
# 2                                   1.63
# 3                                   1.60
# 4                                   1.60

# %%
features.isna().sum()
# Out:
# Date                                     0
# House_Price_Index(S&P/Case-Shiller)      0
# Mortgage_Rate (30 yers)                  0
# Personal_Income                          0
# Resident_Population                      0
# Unemployment_Rate                        0
# GDP                                      0
# Crime_Rate                               0
# Median_Debt                              0
# New_Structures                           0
# Economic_Conditions_Index                0
# CPI all items less shelter               0
# Percent_With_Mortgage_Debt               0
# Percent_With_Severely_Delinquent_Debt    0
# dtype: int64

# %%
features=features.drop('Date',axis=1)
train_dataset = features.iloc[:154]
test_dataset = features.iloc[154:]

# %%
train_dataset
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                             168.016174                     5.93
# 1                             167.616675                     5.86
# 2                             167.717165                     5.72
# 3                             167.155395                     5.58
# 4                             166.556535                     5.70
# ..                                   ...                      ...
# 149                           142.383146                     3.88
# 150                           143.084706                     3.81
# 151                           143.920804                     3.90
# 152                           144.291681                     3.92
# 153                           144.192156                     3.95
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0        40731.00000           9362.08000                6.2  471401.4910
# 1        41006.90000           9365.75750                6.1  473749.3002
# 2        41282.80000           9369.43500                6.0  476097.1094
# 3        41558.70000           9373.11250                6.4  478444.9186
# 4        41834.60000           9376.79000                6.0  480792.7278
# ..               ...                  ...                ...          ...
# 149      60262.41667           9496.63925                5.3  677682.0074
# 150      60538.33333           9494.14300                4.6  680403.2893
# 151      60814.25000           9491.64675                4.5  683124.5713
# 152      61090.16667           9489.15050                4.4  685845.8532
# 153      61366.08333           9486.65425                4.4  688567.1351
#
#       Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    1195.605000  177440.0000            4629                       1.68
# 1    1195.605000  177931.6667            4585                       2.00
# 2    1195.605000  178423.3333            4618                       1.43
# 3    1195.605000  178915.0000            4476                       1.44
# 4    1195.605000  179127.6667            4920                       2.00
# ..           ...          ...             ...                        ...
# 149  1101.066667  164783.3333            1785                       1.56
# 150  1100.515000  164838.0000            1810                       1.79
# 151  1099.963333  164832.3333            1895                       1.75
# 152  1099.411667  164826.6667            1499                       1.89
# 153  1098.860000  164821.0000            1699                       1.94
#
#      CPI all items less shelter  Percent_With_Mortgage_Debt  \
# 0                       175.200                       43.50
# 1                       177.300                       43.50
# 2                       176.900                       43.50
# 3                       177.000                       43.50
# 4                       177.300                       43.47
# ..                          ...                         ...
# 149                     211.010                       35.97
# 150                     211.699                       35.80
# 151                     210.498                       35.70
# 152                     211.096                       35.60
# 153                     210.373                       35.50
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                     1.70
# 1                                     1.67
# 2                                     1.63
# 3                                     1.60
# 4                                     1.60
# ..                                     ...
# 149                                   1.80
# 150                                   1.80
# 151                                   1.80
# 152                                   1.80
# 153                                   1.80
#
# [154 rows x 13 columns]

# %%
train_stats = train_dataset.describe()
train_stats.pop('House_Price_Index(S&P/Case-Shiller)')
train_stats = train_stats.transpose()
train_stats
# Out:
#                                        count           mean           std  \
# Mortgage_Rate (30 yers)                154.0       4.769286      1.037777
# Personal_Income                        154.0   49410.840909   5558.791948
# Resident_Population                    154.0    9507.441208     51.479097
# Unemployment_Rate                      154.0       7.238312      2.234027
# GDP                                    154.0  563331.657740  61986.950619
# Crime_Rate                             154.0    1061.098828    112.031209
# Median_Debt                            154.0  178663.032468  10221.608714
# New_Structures                         154.0    1685.837662   1294.537965
# Economic_Conditions_Index              154.0       1.082792      1.830529
# CPI all items less shelter             154.0     199.183299     10.638096
# Percent_With_Mortgage_Debt             154.0      41.146104      3.084190
# Percent_With_Severely_Delinquent_Debt  154.0       3.992208      2.114689
#
#                                               min            25%  \
# Mortgage_Rate (30 yers)                     3.350       3.912500
# Personal_Income                         40731.000   44874.875000
# Resident_Population                      9362.080    9488.442792
# Unemployment_Rate                           3.700       5.300000
# GDP                                    471401.491  509408.407975
# Crime_Rate                                884.000     966.479375
# Median_Debt                            164465.000  167645.750025
# New_Structures                            235.000     713.750000
# Economic_Conditions_Index                  -6.130       1.117500
# CPI all items less shelter                175.200     190.724000
# Percent_With_Mortgage_Debt                 35.500      38.202500
# Percent_With_Severely_Delinquent_Debt       1.500       2.000000
#
#                                                  50%            75%  \
# Mortgage_Rate (30 yers)                     4.430000       5.850000
# Personal_Income                         47609.208335   54746.687500
# Resident_Population                      9520.838125    9547.500750
# Unemployment_Rate                           6.400000       9.400000
# GDP                                    548150.406150  624409.768925
# Crime_Rate                               1073.052250    1181.177437
# Median_Debt                            179021.333350  189092.499975
# New_Structures                           1204.500000    2098.000000
# Economic_Conditions_Index                   1.720000       2.007500
# CPI all items less shelter                203.751000     207.761250
# Percent_With_Mortgage_Debt                 42.065000      43.875000
# Percent_With_Severely_Delinquent_Debt       3.400000       6.382500
#
#                                                 max
# Mortgage_Rate (30 yers)                     6.76000
# Personal_Income                         61366.08333
# Resident_Population                      9580.56700
# Unemployment_Rate                          12.20000
# GDP                                    688567.13510
# Crime_Rate                               1208.60100
# Median_Debt                            193843.00000
# New_Structures                           5641.00000
# Economic_Conditions_Index                   2.78000
# CPI all items less shelter                213.74900
# Percent_With_Mortgage_Debt                 45.30000
# Percent_With_Severely_Delinquent_Debt       7.30000

# %%
train_labels = train_dataset.pop('House_Price_Index(S&P/Case-Shiller)')
test_labels = test_dataset.pop('House_Price_Index(S&P/Case-Shiller)')

# %%
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
normed_train_data.head(20)
# Out:
#     Mortgage_Rate (30 yers)  Personal_Income  Resident_Population  \
# 0                  1.118462        -1.561462            -2.823694
# 1                  1.051011        -1.511829            -2.752257
# 2                  0.916107        -1.462196            -2.680820
# 3                  0.781203        -1.412562            -2.609384
# 4                  0.896835        -1.362929            -2.537947
# 5                  1.012467        -1.313296            -2.466510
# 6                  0.964287        -1.263663            -2.395073
# 7                  1.253366        -1.214030            -2.323636
# 8                  1.503902        -1.164397            -2.252200
# 9                  1.446086        -1.114764            -2.180763
# 10                 1.330454        -1.065131            -2.109326
# 11                 1.426814        -1.028717            -2.023400
# 12                 1.494266        -0.992303            -1.937473
# 13                 1.677350        -0.955890            -1.851547
# 14                 1.764073        -0.919476            -1.765620
# 15                 1.841161        -0.883062            -1.679694
# 16                 1.918249        -0.846648            -1.593767
# 17                 1.686985        -0.810234            -1.507841
# 18                 1.571354        -0.773821            -1.421914
# 19                 1.532810        -0.737407            -1.335988
#
#     Unemployment_Rate       GDP  Crime_Rate  Median_Debt  New_Structures  \
# 0           -0.464771 -1.483057    1.200613    -0.119652        2.273523
# 1           -0.509534 -1.445181    1.200613    -0.071551        2.239534
# 2           -0.554296 -1.407305    1.200613    -0.023450        2.265026
# 3           -0.375247 -1.369429    1.200613     0.024650        2.155335
# 4           -0.554296 -1.331553    1.200613     0.045456        2.498314
# 5           -0.778107 -1.293677    1.200613     0.066262        3.055269
# 6           -0.778107 -1.255802    1.200613     0.087067        2.480547
# 7           -0.957156 -1.217926    1.200613     0.163637        2.295153
# 8           -0.912394 -1.180050    1.200613     0.240207        2.133705
# 9           -0.957156 -1.142174    1.200613     0.316777        1.778366
# 10          -0.867631 -1.104298    1.190412     0.403293        1.705753
# 11          -0.867631 -1.077650    1.180210     0.489809        1.899645
# 12          -1.046680 -1.051003    1.170008     0.576325        2.176964
# 13          -1.091442 -1.024355    1.159806     0.595761        1.916639
# 14          -1.270491 -0.997707    1.149605     0.615197        2.469732
# 15          -1.091442 -0.971060    1.139403     0.634633        1.833212
# 16          -1.091442 -0.944412    1.129201     0.684592        2.108213
# 17          -1.180967 -0.917765    1.118999     0.734552        2.065727
# 18          -1.404778 -0.891117    1.108797     0.784511        1.316425
# 19          -1.583827 -0.864469    1.098596     0.869723        1.454698
#
#     Economic_Conditions_Index  CPI all items less shelter  \
# 0                    0.326249                   -2.254473
# 1                    0.501062                   -2.057069
# 2                    0.189676                   -2.094670
# 3                    0.195139                   -2.085270
# 4                    0.501062                   -2.057069
# 5                    0.391804                   -1.897266
# 6                    0.342637                   -1.521259
# 7                    0.364489                   -1.530659
# 8                    0.419118                   -1.643461
# 9                    0.506525                   -1.793864
# 10                   0.796058                   -1.652861
# 11                   0.654023                   -1.728063
# 12                   0.424581                   -1.681062
# 13                   0.260694                   -1.690462
# 14                   0.113196                   -1.624661
# 15                   0.085881                   -1.615261
# 16                  -0.121709                   -1.587060
# 17                  -0.067080                   -1.483658
# 18                  -0.012451                   -1.568260
# 19                   0.014863                   -1.925467
#
#     Percent_With_Mortgage_Debt  Percent_With_Severely_Delinquent_Debt
# 0                     0.763214                              -1.083946
# 1                     0.763214                              -1.098132
# 2                     0.763214                              -1.117047
# 3                     0.763214                              -1.131234
# 4                     0.753487                              -1.131234
# 5                     0.740517                              -1.131234
# 6                     0.730790                              -1.131234
# 7                     0.698367                              -1.131234
# 8                     0.665943                              -1.131234
# 9                     0.633520                              -1.131234
# 10                    0.708094                              -1.131234
# 11                    0.785910                              -1.131234
# 12                    0.860484                              -1.131234
# 13                    0.892907                              -1.145420
# 14                    0.925331                              -1.164336
# 15                    0.957754                              -1.178522
# 16                    0.967481                              -1.145420
# 17                    0.980451                              -1.117047
# 18                    0.990178                              -1.083946
# 19                    0.967481                              -1.083946

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                832
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,057
# Trainable params: 5,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[-0.6006133 ],
#        [-0.61424816],
#        [-0.6467608 ],
#        [-0.6199715 ],
#        [-0.64305073],
#        [-0.7715192 ],
#        [-0.7541609 ],
#        [-0.7025005 ],
#        [-0.61011994],
#        [-0.52102   ]], dtype=float32)

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 400

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [pressure2]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,200])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [pressure2^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,40000])
  plt.legend()
  plt.show()


plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-132209ce9510> in <module>
#      25
#      26
# ---> 27 plot_history(history)
#
# <ipython-input-14-132209ce9510> in plot_history(history)
#       8   plt.plot(hist['epoch'], hist['mae'],
#       9            label='Train Error')
# ---> 10   plt.plot(hist['epoch'], hist['val_mae'],
#      11            label = 'Val Error')
#      12   plt.ylim([0,200])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'

# %%
test_predictions = model.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 250]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

test_errors = abs(test_predictions - test_labels)


print('Mean Absolute Error:', round(np.mean(test_errors), 2))

mape = np.mean(100 * (test_errors / test_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 1.34
# Accuracy: 99.07 %.

# %%
train_predictions = model.predict(normed_train_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(train_labels, train_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 220]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
train_errors = abs(train_predictions - train_labels)


print('Mean Absolute Error:', round(np.mean(train_errors), 2))

mape = np.mean(100 * (train_errors / train_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 1.66
# Accuracy: 98.77 %.

# %%
prediction_features=features   #produce prediction result
prediction_features
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                             168.016174                     5.93
# 1                             167.616675                     5.86
# 2                             167.717165                     5.72
# 3                             167.155395                     5.58
# 4                             166.556535                     5.70
# ..                                   ...                      ...
# 161                           144.422443                     4.55
# 162                           143.719229                     4.63
# 163                           144.269699                     4.83
# 164                           144.419653                     4.87
# 165                           145.127952                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0        40731.00000          9362.080000                6.2  471401.4910
# 1        41006.90000          9365.757500                6.1  473749.3002
# 2        41282.80000          9369.435000                6.0  476097.1094
# 3        41558.70000          9373.112500                6.4  478444.9186
# 4        41834.60000          9376.790000                6.0  480792.7278
# ..               ...                  ...                ...          ...
# 161      62725.83333          9469.213583                4.1  701713.5118
# 162      62880.66667          9467.078667                3.7  703202.8110
# 163      63035.50000          9464.943750                3.9  704692.1103
# 164      63190.33333          9462.808833                3.6  706181.4095
# 165      63345.16667          9460.673917                4.0  707670.7088
#
#       Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    1195.605000  177440.0000            4629                       1.68
# 1    1195.605000  177931.6667            4585                       2.00
# 2    1195.605000  178423.3333            4618                       1.43
# 3    1195.605000  178915.0000            4476                       1.44
# 4    1195.605000  179127.6667            4920                       2.00
# ..           ...          ...             ...                        ...
# 161  1037.013333  164680.0000            1615                       1.51
# 162  1029.282500  165003.0000            1583                       1.35
# 163  1021.551667  165081.0000            1736                       1.35
# 164  1013.820833  165159.0000            2011                       1.44
# 165  1006.090000  165237.0000            1064                       1.34
#
#      CPI all items less shelter  Percent_With_Mortgage_Debt  \
# 0                       175.200                       43.50
# 1                       177.300                       43.50
# 2                       176.900                       43.50
# 3                       177.000                       43.50
# 4                       177.300                       43.47
# ..                          ...                         ...
# 161                     212.840                       35.80
# 162                     213.605                       35.80
# 163                     213.241                       35.67
# 164                     211.004                       35.53
# 165                     209.956                       35.40
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                     1.70
# 1                                     1.67
# 2                                     1.63
# 3                                     1.60
# 4                                     1.60
# ..                                     ...
# 161                                   1.43
# 162                                   1.40
# 163                                   1.40
# 164                                   1.40
# 165                                   1.40
#
# [166 rows x 13 columns]

# %%
prediction_features.pop('House_Price_Index(S&P/Case-Shiller)')
normed_prediction_features=norm(prediction_features)
prediction_result=model.predict(normed_prediction_features)
prediction_result=pd.DataFrame(prediction_result)
rawdataset=raw_dataset.join(prediction_result)
rawdataset
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0     3/1/2005                           168.016174                     5.93
# 1     4/1/2005                           167.616675                     5.86
# 2     5/1/2005                           167.717165                     5.72
# 3     6/1/2005                           167.155395                     5.58
# 4     7/1/2005                           166.556535                     5.70
# ..         ...                                  ...                      ...
# 161   8/1/2018                           144.422443                     4.55
# 162   9/1/2018                           143.719229                     4.63
# 163  10/1/2018                           144.269699                     4.83
# 164  11/1/2018                           144.419653                     4.87
# 165  12/1/2018                           145.127952                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0        40731.00000          9362.080000                6.2  471401.4910
# 1        41006.90000          9365.757500                6.1  473749.3002
# 2        41282.80000          9369.435000                6.0  476097.1094
# 3        41558.70000          9373.112500                6.4  478444.9186
# 4        41834.60000          9376.790000                6.0  480792.7278
# ..               ...                  ...                ...          ...
# 161      62725.83333          9469.213583                4.1  701713.5118
# 162      62880.66667          9467.078667                3.7  703202.8110
# 163      63035.50000          9464.943750                3.9  704692.1103
# 164      63190.33333          9462.808833                3.6  706181.4095
# 165      63345.16667          9460.673917                4.0  707670.7088
#
#       Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 0    1195.605000                     43.50%  177440.0000
# 1    1195.605000                     43.50%  177931.6667
# 2    1195.605000                     43.50%  178423.3333
# 3    1195.605000                     43.50%  178915.0000
# 4    1195.605000                     43.47%  179127.6667
# ..           ...                        ...          ...
# 161  1037.013333                     35.80%  164680.0000
# 162  1029.282500                     35.80%  165003.0000
# 163  1021.551667                     35.67%  165081.0000
# 164  1013.820833                     35.53%  165159.0000
# 165  1006.090000                     35.40%  165237.0000
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 0                                   1.70%            4629
# 1                                   1.67%            4585
# 2                                   1.63%            4618
# 3                                   1.60%            4476
# 4                                   1.60%            4920
# ..                                    ...             ...
# 161                                 1.43%            1615
# 162                                 1.40%            1583
# 163                                 1.40%            1736
# 164                                 1.40%            2011
# 165                                 1.40%            1064
#
#      Economic_Conditions_Index  CPI all items less shelter           0
# 0                         1.68                     175.200  171.203903
# 1                         2.00                     177.300  169.905121
# 2                         1.43                     176.900  167.799530
# 3                         1.44                     177.000  164.243103
# 4                         2.00                     177.300  167.085846
# ..                         ...                         ...         ...
# 161                       1.51                     212.840  144.967651
# 162                       1.35                     213.605  145.261002
# 163                       1.35                     213.241  145.225220
# 164                       1.44                     211.004  145.042419
# 165                       1.34                     209.956  145.919022
#
# [166 rows x 15 columns]

# %%
rawdataset.to_csv('prediction-result.csv',index = False, header=True)

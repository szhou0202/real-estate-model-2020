# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.2.0

# %%
raw_dataset = pd.read_csv('NY data summary Interpolated (1Y).csv',
                      na_values = "?", comment='\t',
                      sep=",", skipinitialspace=True)

features = raw_dataset.copy()

features.tail(20)
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 146   5/1/2017                           197.922307                     4.01
# 147   6/1/2017                           198.046348                     3.90
# 148   7/1/2017                           198.113635                     3.97
# 149   8/1/2017                           198.477340                     3.88
# 150   9/1/2017                           198.605966                     3.81
# 151  10/1/2017                           200.036857                     3.90
# 152  11/1/2017                           200.792924                     3.92
# 153  12/1/2017                           201.410302                     3.95
# 154   1/1/2018                           201.580859                     4.03
# 155   2/1/2018                           201.556531                     4.33
# 156   3/1/2018                           201.165615                     4.44
# 157   4/1/2018                           201.119760                     4.47
# 158   5/1/2018                           201.226378                     4.59
# 159   6/1/2018                           200.791822                     4.57
# 160   7/1/2018                           200.507694                     4.53
# 161   8/1/2018                           200.605986                     4.55
# 162   9/1/2018                           200.291101                     4.63
# 163  10/1/2018                           201.912761                     4.83
# 164  11/1/2018                           202.467357                     4.87
# 165  12/1/2018                           203.410280                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 146      74250.33333          19307.28600                4.5  1732978.962
# 147      74539.66667          19303.45575                4.6  1741250.132
# 148      74829.00000          19299.62550                4.6  1749521.303
# 149      75118.33333          19295.79525                4.6  1757792.473
# 150      75407.66667          19291.96500                4.6  1766063.643
# 151      75697.00000          19288.13475                4.5  1774334.813
# 152      75986.33333          19284.30450                4.5  1782605.984
# 153      76275.66667          19280.47425                4.4  1790877.154
# 154      76565.00000          19276.64400                4.3  1799148.324
# 155      76838.25000          19271.60550                4.3  1804314.915
# 156      77111.50000          19266.56700                4.2  1809481.505
# 157      77384.75000          19261.52850                4.1  1814648.096
# 158      77658.00000          19256.49000                4.1  1819814.686
# 159      77931.25000          19251.45150                4.0  1824981.277
# 160      78204.50000          19246.41300                3.9  1830147.867
# 161      78477.75000          19241.37450                3.8  1835314.458
# 162      78751.00000          19236.33600                3.8  1840481.048
# 163      79024.25000          19231.29750                3.8  1845647.639
# 164      79297.50000          19226.25900                3.8  1850814.229
# 165      79570.75000          19221.22050                3.9  1855980.820
#
#      Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 146  561.908500                     28.40%  245291.6667
# 147  559.031825                     28.40%  245422.0000
# 148  556.155150                     28.27%  245491.6667
# 149  553.278475                     28.13%  245561.3333
# 150  550.401800                     28.00%  245631.0000
# 151  547.525125                     27.90%  245540.3333
# 152  544.648450                     27.80%  245449.6667
# 153  541.771775                     27.70%  245359.0000
# 154  538.895100                     27.83%  245047.3333
# 155  539.073092                     27.97%  244735.6667
# 156  539.251083                     28.10%  244424.0000
# 157  539.429075                     27.93%  244326.3333
# 158  539.607067                     27.77%  244228.6667
# 159  539.785058                     27.60%  244131.0000
# 160  539.963050                     27.67%  244501.3333
# 161  540.141042                     27.73%  244871.6667
# 162  540.319033                     27.80%  245242.0000
# 163  540.497025                     27.53%  245087.0000
# 164  540.675017                     27.27%  244932.0000
# 165  540.853008                     27.00%  244777.0000
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 146                                 2.70%     5466.221827
# 147                                 2.60%     3850.093982
# 148                                 2.57%     4010.836341
# 149                                 2.53%     3118.553708
# 150                                 2.50%     2928.686450
# 151                                 2.47%     3500.473181
# 152                                 2.43%     3968.326158
# 153                                 2.40%     3379.406569
# 154                                 2.33%     4598.873831
# 155                                 2.27%     4467.467264
# 156                                 2.20%     3745.519561
# 157                                 2.13%     4214.956696
# 158                                 2.07%     3579.048955
# 159                                 2.00%     3977.728696
# 160                                 1.97%     4260.503262
# 161                                 1.93%     5090.556959
# 162                                 1.90%     4911.314579
# 163                                 1.90%     6074.946755
# 164                                 1.90%     6341.929028
# 165                                 1.90%     4781.127861
#
#      Economic_Conditions_Index  CPI less shelter
# 146                       2.80           228.984
# 147                       3.07           229.351
# 148                       3.04           228.127
# 149                       2.92           228.207
# 150                       2.79           230.219
# 151                       2.54           229.361
# 152                       2.71           228.960
# 153                       2.81           228.871
# 154                       2.90           230.297
# 155                       2.94           232.256
# 156                       2.77           231.599
# 157                       2.72           232.455
# 158                       2.69           233.694
# 159                       2.58           234.083
# 160                       2.32           233.478
# 161                       2.62           233.643
# 162                       2.92           234.836
# 163                       2.96           234.245
# 164                       2.92           233.082
# 165                       3.02           231.888

# %%
mort_debt = np.array(features['Percent_With_Mortgage_Debt'])
mdebt = []
for x in mort_debt:
  mdebt.append(float(x[:5]))
features = features.drop('Percent_With_Mortgage_Debt',axis=1)

del_debt = np.array(features['Percent_With_Severely_Delinquent_Debt'])
ddebt = []
for x in del_debt:
  ddebt.append(float(x[:4]))
features = features.drop('Percent_With_Severely_Delinquent_Debt',axis=1)

features['Percent_With_Mortgage_Debt'] = mdebt
features['Percent_With_Severely_Delinquent_Debt'] = ddebt
features.head()
# Out:
#        Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0  3/1/2005                           215.719341                     5.93
# 1  4/1/2005                           216.433534                     5.86
# 2  5/1/2005                           216.619664                     5.72
# 3  6/1/2005                           216.195575                     5.58
# 4  7/1/2005                           215.050631                     5.70
#
#    Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0          46445.0           18798.1140                4.8  1096833.984
# 1          46844.7           18800.8659                4.8  1102432.129
# 2          47244.4           18803.6178                4.7  1108030.274
# 3          47644.1           18806.3697                4.8  1113628.419
# 4          48043.8           18809.1216                4.8  1119226.564
#
#    Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0   687.39410     214701.0     5852.065587                       2.39
# 1   685.96012     215126.0     4700.094832                       2.74
# 2   684.52614     215551.0     4978.336136                       2.65
# 3   683.09216     215976.0     4541.492838                       2.49
# 4   681.65818     216901.0     4545.705558                       2.50
#
#    CPI less shelter  Percent_With_Mortgage_Debt  \
# 0             186.9                       32.90
# 1             187.9                       32.90
# 2             188.4                       32.90
# 3             187.6                       32.90
# 4             189.2                       32.83
#
#    Percent_With_Severely_Delinquent_Debt
# 0                                   0.90
# 1                                   0.87
# 2                                   0.83
# 3                                   0.80
# 4                                   0.83

# %%
features.isna().sum()
# Out:
# Date                                     0
# House_Price_Index(S&P/Case-Shiller)      0
# Mortgage_Rate (30 yers)                  0
# Personal_Income                          0
# Resident_Population                      0
# Unemployment_Rate                        0
# GDP                                      0
# Crime_Rate                               0
# Median_Debt                              0
# New_Structures                           0
# Economic_Conditions_Index                0
# CPI less shelter                         0
# Percent_With_Mortgage_Debt               0
# Percent_With_Severely_Delinquent_Debt    0
# dtype: int64

# %%
features=features.drop('Date',axis=1)
train_dataset = features.iloc[:154]
test_dataset = features.iloc[154:]

# %%
train_dataset
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                             215.719341                     5.93
# 1                             216.433534                     5.86
# 2                             216.619664                     5.72
# 3                             216.195575                     5.58
# 4                             215.050631                     5.70
# ..                                   ...                      ...
# 149                           198.477340                     3.88
# 150                           198.605966                     3.81
# 151                           200.036857                     3.90
# 152                           200.792924                     3.92
# 153                           201.410302                     3.95
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0        46445.00000          18798.11400                4.8  1096833.984
# 1        46844.70000          18800.86590                4.8  1102432.129
# 2        47244.40000          18803.61780                4.7  1108030.274
# 3        47644.10000          18806.36970                4.8  1113628.419
# 4        48043.80000          18809.12160                4.8  1119226.564
# ..               ...                  ...                ...          ...
# 149      75118.33333          19295.79525                4.6  1757792.473
# 150      75407.66667          19291.96500                4.6  1766063.643
# 151      75697.00000          19288.13475                4.5  1774334.813
# 152      75986.33333          19284.30450                4.5  1782605.984
# 153      76275.66667          19280.47425                4.4  1790877.154
#
#      Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    687.394100  214701.0000     5852.065587                       2.39
# 1    685.960120  215126.0000     4700.094832                       2.74
# 2    684.526140  215551.0000     4978.336136                       2.65
# 3    683.092160  215976.0000     4541.492838                       2.49
# 4    681.658180  216901.0000     4545.705558                       2.50
# ..          ...          ...             ...                        ...
# 149  553.278475  245561.3333     3118.553708                       2.92
# 150  550.401800  245631.0000     2928.686450                       2.79
# 151  547.525125  245540.3333     3500.473181                       2.54
# 152  544.648450  245449.6667     3968.326158                       2.71
# 153  541.771775  245359.0000     3379.406569                       2.81
#
#      CPI less shelter  Percent_With_Mortgage_Debt  \
# 0             186.900                       32.90
# 1             187.900                       32.90
# 2             188.400                       32.90
# 3             187.600                       32.90
# 4             189.200                       32.83
# ..                ...                         ...
# 149           228.207                       28.13
# 150           230.219                       28.00
# 151           229.361                       27.90
# 152           228.960                       27.80
# 153           228.871                       27.70
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                     0.90
# 1                                     0.87
# 2                                     0.83
# 3                                     0.80
# 4                                     0.83
# ..                                     ...
# 149                                   2.53
# 150                                   2.50
# 151                                   2.47
# 152                                   2.43
# 153                                   2.40
#
# [154 rows x 13 columns]

# %%
train_stats = train_dataset.describe()
train_stats.pop('House_Price_Index(S&P/Case-Shiller)')
train_stats = train_stats.transpose()
train_stats
# Out:
#                                        count          mean            std  \
# Mortgage_Rate (30 yers)                154.0  4.769286e+00       1.037777
# Personal_Income                        154.0  5.993081e+04    7510.820739
# Resident_Population                    154.0  1.911108e+04     178.412287
# Unemployment_Rate                      154.0  6.403896e+00       1.829778
# GDP                                    154.0  1.391972e+06  196649.253629
# Crime_Rate                             154.0  6.067952e+02      35.692835
# Median_Debt                            154.0  2.437323e+05    9064.575554
# New_Structures                         154.0  3.455813e+03    2312.150506
# Economic_Conditions_Index              154.0  2.360584e+00       1.351554
# CPI less shelter                       154.0  2.153250e+02      12.967668
# Percent_With_Mortgage_Debt             154.0  3.188377e+01       1.994064
# Percent_With_Severely_Delinquent_Debt  154.0  4.385065e+00       2.358034
#
#                                                 min           25%  \
# Mortgage_Rate (30 yers)                3.350000e+00  3.912500e+00
# Personal_Income                        4.644500e+04  5.420160e+04
# Resident_Population                    1.879811e+04  1.895796e+04
# Unemployment_Rate                      4.200000e+00  4.800000e+00
# GDP                                    1.096834e+06  1.201965e+06
# Crime_Rate                             5.417718e+02  5.787190e+02
# Median_Debt                            2.147010e+05  2.443247e+05
# New_Structures                         1.017219e+03  1.895782e+03
# Economic_Conditions_Index             -3.190000e+00  2.355000e+00
# CPI less shelter                       1.869000e+02  2.047545e+02
# Percent_With_Mortgage_Debt             2.770000e+01  3.040250e+01
# Percent_With_Severely_Delinquent_Debt  8.000000e-01  2.440000e+00
#
#                                                 50%           75%  \
# Mortgage_Rate (30 yers)                4.430000e+00  5.850000e+00
# Personal_Income                        5.891883e+04  6.547181e+04
# Resident_Population                    1.910527e+04  1.929542e+04
# Unemployment_Rate                      5.750000e+00  8.500000e+00
# GDP                                    1.359327e+06  1.558194e+06
# Crime_Rate                             6.030705e+02  6.311594e+02
# Median_Debt                            2.455643e+05  2.487424e+05
# New_Structures                         3.284193e+03  4.370401e+03
# Economic_Conditions_Index              2.750000e+00  3.040000e+00
# CPI less shelter                       2.214430e+02  2.263057e+02
# Percent_With_Mortgage_Debt             3.270000e+01  3.353000e+01
# Percent_With_Severely_Delinquent_Debt  4.635000e+00  6.800000e+00
#
#                                                 max
# Mortgage_Rate (30 yers)                6.760000e+00
# Personal_Income                        7.627567e+04
# Resident_Population                    1.933478e+04
# Unemployment_Rate                      9.300000e+00
# GDP                                    1.790877e+06
# Crime_Rate                             6.873941e+02
# Median_Debt                            2.531410e+05
# New_Structures                         1.751628e+04
# Economic_Conditions_Index              4.050000e+00
# CPI less shelter                       2.302770e+02
# Percent_With_Mortgage_Debt             3.420000e+01
# Percent_With_Severely_Delinquent_Debt  7.500000e+00

# %%
train_labels = train_dataset.pop('House_Price_Index(S&P/Case-Shiller)')
test_labels = test_dataset.pop('House_Price_Index(S&P/Case-Shiller)')

# %%
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
normed_train_data.head(20)
# Out:
#     Mortgage_Rate (30 yers)  Personal_Income  Resident_Population  \
# 0                  1.118462        -1.795518            -1.754158
# 1                  1.051011        -1.742301            -1.738734
# 2                  0.916107        -1.689085            -1.723309
# 3                  0.781203        -1.635868            -1.707885
# 4                  0.896835        -1.582651            -1.692461
# 5                  1.012467        -1.529435            -1.677036
# 6                  0.964287        -1.476218            -1.661612
# 7                  1.253366        -1.423002            -1.646187
# 8                  1.503902        -1.369785            -1.630763
# 9                  1.446086        -1.316569            -1.615339
# 10                 1.330454        -1.263352            -1.599914
# 11                 1.426814        -1.220403            -1.564634
# 12                 1.494266        -1.177454            -1.529353
# 13                 1.677350        -1.134505            -1.494072
# 14                 1.764073        -1.091556            -1.458792
# 15                 1.841161        -1.048606            -1.423511
# 16                 1.918249        -1.005657            -1.388230
# 17                 1.686985        -0.962708            -1.352950
# 18                 1.571354        -0.919759            -1.317669
# 19                 1.532810        -0.876810            -1.282388
#
#     Unemployment_Rate       GDP  Crime_Rate  Median_Debt  New_Structures  \
# 0           -0.876552 -1.500836    2.258124    -3.202725        1.036374
# 1           -0.876552 -1.472369    2.217949    -3.155839        0.538149
# 2           -0.931203 -1.443901    2.177773    -3.108954        0.658488
# 3           -0.876552 -1.415433    2.137597    -3.062068        0.469554
# 4           -0.876552 -1.386966    2.097422    -2.960022        0.471376
# 5           -0.821901 -1.358498    2.057246    -2.857977        0.946813
# 6           -0.767249 -1.330030    2.017071    -2.755931        0.641884
# 7           -0.767249 -1.301563    1.976895    -2.629174        0.354601
# 8           -0.767249 -1.273095    1.936720    -2.502417        0.432631
# 9           -0.821901 -1.244627    1.896544    -2.375659        0.492449
# 10          -0.821901 -1.216160    1.856368    -2.207238        0.903523
# 11          -0.876552 -1.197279    1.774334    -2.038817        0.465152
# 12          -0.876552 -1.178399    1.692300    -1.870396        0.475543
# 13          -0.876552 -1.159518    1.610266    -1.793540        0.662652
# 14          -0.876552 -1.140638    1.528232    -1.716684        0.400874
# 15          -0.931203 -1.121758    1.446197    -1.639828        0.509052
# 16          -0.985855 -1.102877    1.364163    -1.556206        0.721828
# 17          -1.040506 -1.083997    1.282129    -1.472583        0.399378
# 18          -1.095158 -1.065116    1.200095    -1.388961        0.302272
# 19          -1.149809 -1.046236    1.118061    -1.242567        0.609336
#
#     Economic_Conditions_Index  CPI less shelter  Percent_With_Mortgage_Debt  \
# 0                    0.021764         -2.191989                    0.509630
# 1                    0.280726         -2.114874                    0.509630
# 2                    0.214135         -2.076316                    0.509630
# 3                    0.095753         -2.138008                    0.509630
# 4                    0.103152         -2.014624                    0.474525
# 5                   -0.089219         -1.852683                    0.444436
# 6                   -0.318585         -1.528801                    0.409332
# 7                   -0.274191         -1.605916                    0.374228
# 8                   -0.067022         -1.713876                    0.344138
# 9                    0.080955         -1.814126                    0.309034
# 10                   0.014365         -1.698453                    0.459481
# 11                  -0.044826         -1.729299                    0.609927
# 12                   0.006966         -1.659896                    0.760374
# 13                  -0.074421         -1.544224                    0.795478
# 14                  -0.015230         -1.467109                    0.825567
# 15                   0.177141         -1.413128                    0.860671
# 16                   0.058759         -1.428551                    0.875716
# 17                   0.073557         -1.351437                    0.895776
# 18                   0.051360         -1.413128                    0.910820
# 19                   0.051360         -1.567358                    0.825567
#
#     Percent_With_Severely_Delinquent_Debt
# 0                               -1.477954
# 1                               -1.490676
# 2                               -1.507639
# 3                               -1.520362
# 4                               -1.507639
# 5                               -1.490676
# 6                               -1.477954
# 7                               -1.477954
# 8                               -1.477954
# 9                               -1.477954
# 10                              -1.477954
# 11                              -1.477954
# 12                              -1.477954
# 13                              -1.477954
# 14                              -1.477954
# 15                              -1.477954
# 16                              -1.465231
# 17                              -1.448268
# 18                              -1.435545
# 19                              -1.422823

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                832
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,057
# Trainable params: 5,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[-0.03694779],
#        [ 0.05076189],
#        [ 0.031571  ],
#        [ 0.05930573],
#        [ 0.04148439],
#        [-0.05732003],
#        [-0.03198341],
#        [-0.02180609],
#        [-0.05514203],
#        [-0.04859437]], dtype=float32)

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 400

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [pressure2]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,200])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [pressure2^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,40000])
  plt.legend()
  plt.show()


plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-132209ce9510> in <module>
#      25
#      26
# ---> 27 plot_history(history)
#
# <ipython-input-14-132209ce9510> in plot_history(history)
#       8   plt.plot(hist['epoch'], hist['mae'],
#       9            label='Train Error')
# ---> 10   plt.plot(hist['epoch'], hist['val_mae'],
#      11            label = 'Val Error')
#      12   plt.ylim([0,200])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'

# %%
test_predictions = model.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 250]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

test_errors = abs(test_predictions - test_labels)


print('Mean Absolute Error:', round(np.mean(test_errors), 2))

mape = np.mean(100 * (test_errors / test_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 2.65
# Accuracy: 98.69 %.

# %%
train_predictions = model.predict(normed_train_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(train_labels, train_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 220]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
train_errors = abs(train_predictions - train_labels)


print('Mean Absolute Error:', round(np.mean(train_errors), 2))

mape = np.mean(100 * (train_errors / train_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 1.74
# Accuracy: 99.06 %.

# %%
prediction_features=features   #produce prediction result
prediction_features
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                             215.719341                     5.93
# 1                             216.433534                     5.86
# 2                             216.619664                     5.72
# 3                             216.195575                     5.58
# 4                             215.050631                     5.70
# ..                                   ...                      ...
# 161                           200.605986                     4.55
# 162                           200.291101                     4.63
# 163                           201.912761                     4.83
# 164                           202.467357                     4.87
# 165                           203.410280                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0           46445.00           18798.1140                4.8  1096833.984
# 1           46844.70           18800.8659                4.8  1102432.129
# 2           47244.40           18803.6178                4.7  1108030.274
# 3           47644.10           18806.3697                4.8  1113628.419
# 4           48043.80           18809.1216                4.8  1119226.564
# ..               ...                  ...                ...          ...
# 161         78477.75           19241.3745                3.8  1835314.458
# 162         78751.00           19236.3360                3.8  1840481.048
# 163         79024.25           19231.2975                3.8  1845647.639
# 164         79297.50           19226.2590                3.8  1850814.229
# 165         79570.75           19221.2205                3.9  1855980.820
#
#      Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    687.394100  214701.0000     5852.065587                       2.39
# 1    685.960120  215126.0000     4700.094832                       2.74
# 2    684.526140  215551.0000     4978.336136                       2.65
# 3    683.092160  215976.0000     4541.492838                       2.49
# 4    681.658180  216901.0000     4545.705558                       2.50
# ..          ...          ...             ...                        ...
# 161  540.141042  244871.6667     5090.556959                       2.62
# 162  540.319033  245242.0000     4911.314579                       2.92
# 163  540.497025  245087.0000     6074.946755                       2.96
# 164  540.675017  244932.0000     6341.929028                       2.92
# 165  540.853008  244777.0000     4781.127861                       3.02
#
#      CPI less shelter  Percent_With_Mortgage_Debt  \
# 0             186.900                       32.90
# 1             187.900                       32.90
# 2             188.400                       32.90
# 3             187.600                       32.90
# 4             189.200                       32.83
# ..                ...                         ...
# 161           233.643                       27.73
# 162           234.836                       27.80
# 163           234.245                       27.53
# 164           233.082                       27.27
# 165           231.888                       27.00
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                     0.90
# 1                                     0.87
# 2                                     0.83
# 3                                     0.80
# 4                                     0.83
# ..                                     ...
# 161                                   1.93
# 162                                   1.90
# 163                                   1.90
# 164                                   1.90
# 165                                   1.90
#
# [166 rows x 13 columns]

# %%
prediction_features.pop('House_Price_Index(S&P/Case-Shiller)')
normed_prediction_features=norm(prediction_features)
prediction_result=model.predict(normed_prediction_features)
prediction_result=pd.DataFrame(prediction_result)
rawdataset=raw_dataset.join(prediction_result)
rawdataset
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0     3/1/2005                           215.719341                     5.93
# 1     4/1/2005                           216.433534                     5.86
# 2     5/1/2005                           216.619664                     5.72
# 3     6/1/2005                           216.195575                     5.58
# 4     7/1/2005                           215.050631                     5.70
# ..         ...                                  ...                      ...
# 161   8/1/2018                           200.605986                     4.55
# 162   9/1/2018                           200.291101                     4.63
# 163  10/1/2018                           201.912761                     4.83
# 164  11/1/2018                           202.467357                     4.87
# 165  12/1/2018                           203.410280                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0           46445.00           18798.1140                4.8  1096833.984
# 1           46844.70           18800.8659                4.8  1102432.129
# 2           47244.40           18803.6178                4.7  1108030.274
# 3           47644.10           18806.3697                4.8  1113628.419
# 4           48043.80           18809.1216                4.8  1119226.564
# ..               ...                  ...                ...          ...
# 161         78477.75           19241.3745                3.8  1835314.458
# 162         78751.00           19236.3360                3.8  1840481.048
# 163         79024.25           19231.2975                3.8  1845647.639
# 164         79297.50           19226.2590                3.8  1850814.229
# 165         79570.75           19221.2205                3.9  1855980.820
#
#      Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 0    687.394100                     32.90%  214701.0000
# 1    685.960120                     32.90%  215126.0000
# 2    684.526140                     32.90%  215551.0000
# 3    683.092160                     32.90%  215976.0000
# 4    681.658180                     32.83%  216901.0000
# ..          ...                        ...          ...
# 161  540.141042                     27.73%  244871.6667
# 162  540.319033                     27.80%  245242.0000
# 163  540.497025                     27.53%  245087.0000
# 164  540.675017                     27.27%  244932.0000
# 165  540.853008                     27.00%  244777.0000
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 0                                   0.90%     5852.065587
# 1                                   0.87%     4700.094832
# 2                                   0.83%     4978.336136
# 3                                   0.80%     4541.492838
# 4                                   0.83%     4545.705558
# ..                                    ...             ...
# 161                                 1.93%     5090.556959
# 162                                 1.90%     4911.314579
# 163                                 1.90%     6074.946755
# 164                                 1.90%     6341.929028
# 165                                 1.90%     4781.127861
#
#      Economic_Conditions_Index  CPI less shelter           0
# 0                         2.39           186.900  226.533569
# 1                         2.74           187.900  222.438293
# 2                         2.65           188.400  219.878494
# 3                         2.49           187.600  217.000000
# 4                         2.50           189.200  214.951645
# ..                         ...               ...         ...
# 161                       2.62           233.643  202.718918
# 162                       2.92           234.836  204.424622
# 163                       2.96           234.245  205.228455
# 164                       2.92           233.082  205.469208
# 165                       3.02           231.888  206.236526
#
# [166 rows x 15 columns]

# %%
rawdataset.to_csv('prediction-result.csv',index = False, header=True)

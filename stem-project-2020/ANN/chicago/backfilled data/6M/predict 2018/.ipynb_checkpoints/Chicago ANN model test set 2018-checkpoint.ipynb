# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.2.0

# %%
raw_dataset = pd.read_csv('NY data summary  backfiled（6M）.csv',
                      na_values = "?", comment='\t',
                      sep=",", skipinitialspace=True)

features = raw_dataset.copy()

features.tail(20)
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 146   5/1/2017                           195.324362                     4.01
# 147   6/1/2017                           195.944311                     3.90
# 148   7/1/2017                           196.665120                     3.97
# 149   8/1/2017                           197.782954                     3.88
# 150   9/1/2017                           198.120734                     3.81
# 151  10/1/2017                           197.723899                     3.90
# 152  11/1/2017                           197.922307                     3.92
# 153  12/1/2017                           198.046348                     3.95
# 154   1/1/2018                           198.113635                     4.03
# 155   2/1/2018                           198.477340                     4.33
# 156   3/1/2018                           198.605966                     4.44
# 157   4/1/2018                           200.036857                     4.47
# 158   5/1/2018                           200.792924                     4.59
# 159   6/1/2018                           201.410302                     4.57
# 160   7/1/2018                           201.580859                     4.53
# 161   8/1/2018                           201.556531                     4.55
# 162   9/1/2018                           201.165615                     4.63
# 163  10/1/2018                           201.119760                     4.83
# 164  11/1/2018                           201.226378                     4.87
# 165  12/1/2018                           200.791822                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 146            76565            19276.644                4.5  1799148.324
# 147            76565            19276.644                4.6  1799148.324
# 148            76565            19276.644                4.6  1799148.324
# 149            76565            19276.644                4.6  1799148.324
# 150            76565            19276.644                4.6  1799148.324
# 151            76565            19276.644                4.5  1799148.324
# 152            76565            19276.644                4.5  1799148.324
# 153            76565            19276.644                4.4  1799148.324
# 154            76565            19276.644                4.3  1799148.324
# 155            79844            19216.182                4.3  1861147.410
# 156            79844            19216.182                4.2  1861147.410
# 157            79844            19216.182                4.1  1861147.410
# 158            79844            19216.182                4.1  1861147.410
# 159            79844            19216.182                4.0  1861147.410
# 160            79844            19216.182                3.9  1861147.410
# 161            79844            19216.182                3.8  1861147.410
# 162            79844            19216.182                3.8  1861147.410
# 163            79844            19216.182                3.8  1861147.410
# 164            79844            19216.182                3.8  1861147.410
# 165            79844            19216.182                3.9  1861147.410
#
#      Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 146    538.8951                     28.40%       245422
# 147    538.8951                     28.40%       245422
# 148    538.8951                     28.00%       245631
# 149    538.8951                     28.00%       245631
# 150    538.8951                     28.00%       245631
# 151    538.8951                     27.70%       245359
# 152    538.8951                     27.70%       245359
# 153    538.8951                     27.70%       245359
# 154    541.0310                     28.10%       244424
# 155    541.0310                     28.10%       244424
# 156    541.0310                     28.10%       244424
# 157    541.0310                     27.60%       244131
# 158    541.0310                     27.60%       244131
# 159    541.0310                     27.60%       244131
# 160    541.0310                     27.80%       245242
# 161    541.0310                     27.80%       245242
# 162    541.0310                     27.80%       245242
# 163    541.0310                     27.00%       244777
# 164    541.0310                     27.00%       244777
# 165    541.0310                     27.00%       244777
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 146                                 2.60%     5466.221827
# 147                                 2.60%     3850.093982
# 148                                 2.50%     4010.836341
# 149                                 2.50%     3118.553708
# 150                                 2.50%     2928.686450
# 151                                 2.40%     3500.473181
# 152                                 2.40%     3968.326158
# 153                                 2.40%     3379.406569
# 154                                 2.20%     4598.873831
# 155                                 2.20%     4467.467264
# 156                                 2.20%     3745.519561
# 157                                 2.00%     4214.956696
# 158                                 2.00%     3579.048955
# 159                                 2.00%     3977.728696
# 160                                 1.90%     4260.503262
# 161                                 1.90%     5090.556959
# 162                                 1.90%     4911.314579
# 163                                 1.90%     6074.946755
# 164                                 1.90%     6341.929028
# 165                                 1.90%     4781.127861
#
#      Economic_Conditions_Index  CPI less shelter
# 146                       2.80           228.984
# 147                       3.07           229.351
# 148                       3.04           228.127
# 149                       2.92           228.207
# 150                       2.79           230.219
# 151                       2.54           229.361
# 152                       2.71           228.960
# 153                       2.81           228.871
# 154                       2.90           230.297
# 155                       2.94           232.256
# 156                       2.77           231.599
# 157                       2.72           232.455
# 158                       2.69           233.694
# 159                       2.58           234.083
# 160                       2.32           233.478
# 161                       2.62           233.643
# 162                       2.92           234.836
# 163                       2.96           234.245
# 164                       2.92           233.082
# 165                       3.02           231.888

# %%
mort_debt = np.array(features['Percent_With_Mortgage_Debt'])
mdebt = []
for x in mort_debt:
  mdebt.append(float(x[:5]))
features = features.drop('Percent_With_Mortgage_Debt',axis=1)

del_debt = np.array(features['Percent_With_Severely_Delinquent_Debt'])
ddebt = []
for x in del_debt:
  ddebt.append(float(x[:4]))
features = features.drop('Percent_With_Severely_Delinquent_Debt',axis=1)

features['Percent_With_Mortgage_Debt'] = mdebt
features['Percent_With_Severely_Delinquent_Debt'] = ddebt
features.head()
# Out:
#        Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0  3/1/2005                           204.075072                     5.93
# 1  4/1/2005                           206.680701                     5.86
# 2  5/1/2005                           209.323123                     5.72
# 3  6/1/2005                           212.054408                     5.58
# 4  7/1/2005                           213.506930                     5.70
#
#    Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0            46445            18798.114                4.8  1096833.984
# 1            50442            18825.633                4.8  1152815.433
# 2            50442            18825.633                4.7  1152815.433
# 3            50442            18825.633                4.8  1152815.433
# 4            50442            18825.633                4.8  1152815.433
#
#    Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0    673.0543       214701     5852.065587                       2.39
# 1    673.0543       215976     4700.094832                       2.74
# 2    673.0543       215976     4978.336136                       2.65
# 3    673.0543       215976     4541.492838                       2.49
# 4    673.0543       218751     4545.705558                       2.50
#
#    CPI less shelter  Percent_With_Mortgage_Debt  \
# 0             186.9                        32.9
# 1             187.9                        32.9
# 2             188.4                        32.9
# 3             187.6                        32.9
# 4             189.2                        32.7
#
#    Percent_With_Severely_Delinquent_Debt
# 0                                    0.9
# 1                                    0.8
# 2                                    0.8
# 3                                    0.8
# 4                                    0.9

# %%
features.isna().sum()
# Out:
# Date                                     0
# House_Price_Index(S&P/Case-Shiller)      0
# Mortgage_Rate (30 yers)                  0
# Personal_Income                          0
# Resident_Population                      0
# Unemployment_Rate                        0
# GDP                                      0
# Crime_Rate                               0
# Median_Debt                              0
# New_Structures                           0
# Economic_Conditions_Index                0
# CPI less shelter                         0
# Percent_With_Mortgage_Debt               0
# Percent_With_Severely_Delinquent_Debt    0
# dtype: int64

# %%
features=features.drop('Date',axis=1)
train_dataset = features.iloc[:154]
test_dataset = features.iloc[154:]

# %%
train_dataset
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                             204.075072                     5.93
# 1                             206.680701                     5.86
# 2                             209.323123                     5.72
# 3                             212.054408                     5.58
# 4                             213.506930                     5.70
# ..                                   ...                      ...
# 149                           197.782954                     3.88
# 150                           198.120734                     3.81
# 151                           197.723899                     3.90
# 152                           197.922307                     3.92
# 153                           198.046348                     3.95
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0              46445            18798.114                4.8  1096833.984
# 1              50442            18825.633                4.8  1152815.433
# 2              50442            18825.633                4.7  1152815.433
# 3              50442            18825.633                4.8  1152815.433
# 4              50442            18825.633                4.8  1152815.433
# ..               ...                  ...                ...          ...
# 149            76565            19276.644                4.6  1799148.324
# 150            76565            19276.644                4.6  1799148.324
# 151            76565            19276.644                4.5  1799148.324
# 152            76565            19276.644                4.5  1799148.324
# 153            76565            19276.644                4.4  1799148.324
#
#      Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0      673.0543       214701     5852.065587                       2.39
# 1      673.0543       215976     4700.094832                       2.74
# 2      673.0543       215976     4978.336136                       2.65
# 3      673.0543       215976     4541.492838                       2.49
# 4      673.0543       218751     4545.705558                       2.50
# ..          ...          ...             ...                        ...
# 149    538.8951       245631     3118.553708                       2.92
# 150    538.8951       245631     2928.686450                       2.79
# 151    538.8951       245359     3500.473181                       2.54
# 152    538.8951       245359     3968.326158                       2.71
# 153    538.8951       245359     3379.406569                       2.81
#
#      CPI less shelter  Percent_With_Mortgage_Debt  \
# 0             186.900                        32.9
# 1             187.900                        32.9
# 2             188.400                        32.9
# 3             187.600                        32.9
# 4             189.200                        32.7
# ..                ...                         ...
# 149           228.207                        28.0
# 150           230.219                        28.0
# 151           229.361                        27.7
# 152           228.960                        27.7
# 153           228.871                        27.7
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                      0.9
# 1                                      0.8
# 2                                      0.8
# 3                                      0.8
# 4                                      0.9
# ..                                     ...
# 149                                    2.5
# 150                                    2.5
# 151                                    2.4
# 152                                    2.4
# 153                                    2.4
#
# [154 rows x 13 columns]

# %%
train_stats = train_dataset.describe()
train_stats.pop('House_Price_Index(S&P/Case-Shiller)')
train_stats = train_stats.transpose()
train_stats
# Out:
#                                        count          mean            std  \
# Mortgage_Rate (30 yers)                154.0  4.769286e+00       1.037777
# Personal_Income                        154.0  6.098057e+04    7788.469356
# Resident_Population                    154.0  1.912799e+04     173.707970
# Unemployment_Rate                      154.0  6.403896e+00       1.829778
# GDP                                    154.0  1.416691e+06  204163.929642
# Crime_Rate                             154.0  6.006205e+02      35.908272
# Median_Debt                            154.0  2.439314e+05    8780.198333
# New_Structures                         154.0  3.455813e+03    2312.150506
# Economic_Conditions_Index              154.0  2.360584e+00       1.351554
# CPI less shelter                       154.0  2.153250e+02      12.967668
# Percent_With_Mortgage_Debt             154.0  3.185000e+01       2.025983
# Percent_With_Severely_Delinquent_Debt  154.0  4.394805e+00       2.349935
#
#                                                 min           25%  \
# Mortgage_Rate (30 yers)                3.350000e+00  3.912500e+00
# Personal_Income                        4.644500e+04  5.463200e+04
# Resident_Population                    1.879811e+04  1.896850e+04
# Unemployment_Rate                      4.200000e+00  4.800000e+00
# GDP                                    1.096834e+06  1.225295e+06
# Crime_Rate                             5.388951e+02  5.803423e+02
# Median_Debt                            2.147010e+05  2.444550e+05
# New_Structures                         1.017219e+03  1.895782e+03
# Economic_Conditions_Index             -3.190000e+00  2.355000e+00
# CPI less shelter                       1.869000e+02  2.047545e+02
# Percent_With_Mortgage_Debt             2.770000e+01  3.027500e+01
# Percent_With_Severely_Delinquent_Debt  8.000000e-01  2.400000e+00
#
#                                                 50%           75%  \
# Mortgage_Rate (30 yers)                4.430000e+00  5.850000e+00
# Personal_Income                        6.016000e+04  6.621200e+04
# Resident_Population                    1.914969e+04  1.928093e+04
# Unemployment_Rate                      5.750000e+00  8.500000e+00
# GDP                                    1.401401e+06  1.576387e+06
# Crime_Rate                             5.967001e+02  6.239068e+02
# Median_Debt                            2.456310e+05  2.489982e+05
# New_Structures                         3.284193e+03  4.370401e+03
# Economic_Conditions_Index              2.750000e+00  3.040000e+00
# CPI less shelter                       2.214430e+02  2.263057e+02
# Percent_With_Mortgage_Debt             3.270000e+01  3.357500e+01
# Percent_With_Severely_Delinquent_Debt  4.600000e+00  6.800000e+00
#
#                                                 max
# Mortgage_Rate (30 yers)                6.760000e+00
# Personal_Income                        7.656500e+04
# Resident_Population                    1.933478e+04
# Unemployment_Rate                      9.300000e+00
# GDP                                    1.799148e+06
# Crime_Rate                             6.730543e+02
# Median_Debt                            2.531410e+05
# New_Structures                         1.751628e+04
# Economic_Conditions_Index              4.050000e+00
# CPI less shelter                       2.302770e+02
# Percent_With_Mortgage_Debt             3.420000e+01
# Percent_With_Severely_Delinquent_Debt  7.500000e+00

# %%
train_labels = train_dataset.pop('House_Price_Index(S&P/Case-Shiller)')
test_labels = test_dataset.pop('House_Price_Index(S&P/Case-Shiller)')

# %%
def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
normed_train_data.head(20)
# Out:
#     Mortgage_Rate (30 yers)  Personal_Income  Resident_Population  \
# 0                  1.118462        -1.866294            -1.899021
# 1                  1.051011        -1.353099            -1.740600
# 2                  0.916107        -1.353099            -1.740600
# 3                  0.781203        -1.353099            -1.740600
# 4                  0.896835        -1.353099            -1.740600
# 5                  1.012467        -1.353099            -1.740600
# 6                  0.964287        -1.353099            -1.740600
# 7                  1.253366        -1.353099            -1.740600
# 8                  1.503902        -1.353099            -1.740600
# 9                  1.446086        -1.353099            -1.740600
# 10                 1.330454        -1.353099            -1.740600
# 11                 1.426814        -0.856082            -1.305766
# 12                 1.494266        -0.856082            -1.305766
# 13                 1.677350        -0.856082            -1.305766
# 14                 1.764073        -0.856082            -1.305766
# 15                 1.841161        -0.856082            -1.305766
# 16                 1.918249        -0.856082            -1.305766
# 17                 1.686985        -0.856082            -1.305766
# 18                 1.571354        -0.856082            -1.305766
# 19                 1.532810        -0.856082            -1.305766
#
#     Unemployment_Rate       GDP  Crime_Rate  Median_Debt  New_Structures  \
# 0           -0.876552 -1.566670    2.017189    -3.329130        1.036374
# 1           -0.876552 -1.292471    2.017189    -3.183917        0.538149
# 2           -0.931203 -1.292471    2.017189    -3.183917        0.658488
# 3           -0.876552 -1.292471    2.017189    -3.183917        0.469554
# 4           -0.876552 -1.292471    2.017189    -2.867865        0.471376
# 5           -0.821901 -1.292471    2.017189    -2.867865        0.946813
# 6           -0.767249 -1.292471    2.017189    -2.867865        0.641884
# 7           -0.767249 -1.292471    2.017189    -2.475277        0.354601
# 8           -0.767249 -1.292471    2.017189    -2.475277        0.432631
# 9           -0.821901 -1.292471    2.017189    -2.475277        0.492449
# 10          -0.821901 -1.292471    1.038684    -1.953649        0.903523
# 11          -0.876552 -1.074246    1.038684    -1.953649        0.465152
# 12          -0.876552 -1.074246    1.038684    -1.953649        0.475543
# 13          -0.876552 -1.074246    1.038684    -1.715613        0.662652
# 14          -0.876552 -1.074246    1.038684    -1.715613        0.400874
# 15          -0.931203 -1.074246    1.038684    -1.715613        0.509052
# 16          -0.985855 -1.074246    1.038684    -1.456621        0.721828
# 17          -1.040506 -1.074246    1.038684    -1.456621        0.399378
# 18          -1.095158 -1.074246    1.038684    -1.456621        0.302272
# 19          -1.149809 -1.074246    1.038684    -1.003214        0.609336
#
#     Economic_Conditions_Index  CPI less shelter  Percent_With_Mortgage_Debt  \
# 0                    0.021764         -2.191989                    0.518267
# 1                    0.280726         -2.114874                    0.518267
# 2                    0.214135         -2.076316                    0.518267
# 3                    0.095753         -2.138008                    0.518267
# 4                    0.103152         -2.014624                    0.419549
# 5                   -0.089219         -1.852683                    0.419549
# 6                   -0.318585         -1.528801                    0.419549
# 7                   -0.274191         -1.605916                    0.320832
# 8                   -0.067022         -1.713876                    0.320832
# 9                    0.080955         -1.814126                    0.320832
# 10                   0.014365         -1.698453                    0.765061
# 11                  -0.044826         -1.729299                    0.765061
# 12                   0.006966         -1.659896                    0.765061
# 13                  -0.074421         -1.544224                    0.863778
# 14                  -0.015230         -1.467109                    0.863778
# 15                   0.177141         -1.413128                    0.863778
# 16                   0.058759         -1.428551                    0.913137
# 17                   0.073557         -1.351437                    0.913137
# 18                   0.051360         -1.413128                    0.913137
# 19                   0.051360         -1.567358                    0.666343
#
#     Percent_With_Severely_Delinquent_Debt
# 0                               -1.487192
# 1                               -1.529747
# 2                               -1.529747
# 3                               -1.529747
# 4                               -1.487192
# 5                               -1.487192
# 6                               -1.487192
# 7                               -1.487192
# 8                               -1.487192
# 9                               -1.487192
# 10                              -1.487192
# 11                              -1.487192
# 12                              -1.487192
# 13                              -1.487192
# 14                              -1.487192
# 15                              -1.487192
# 16                              -1.444638
# 17                              -1.444638
# 18                              -1.444638
# 19                              -1.402083

# %%
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                832
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,057
# Trainable params: 5,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[0.1501536 ],
#        [0.07433084],
#        [0.06038903],
#        [0.05257814],
#        [0.1235011 ],
#        [0.157417  ],
#        [0.21446322],
#        [0.28047264],
#        [0.27429706],
#        [0.24538535]], dtype=float32)

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 400

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0, verbose=0,
  callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [pressure2]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.ylim([0,200])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [pressure2^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  plt.ylim([0,40000])
  plt.legend()
  plt.show()


plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-132209ce9510> in <module>
#      25
#      26
# ---> 27 plot_history(history)
#
# <ipython-input-15-132209ce9510> in plot_history(history)
#       8   plt.plot(hist['epoch'], hist['mae'],
#       9            label='Train Error')
# ---> 10   plt.plot(hist['epoch'], hist['val_mae'],
#      11            label = 'Val Error')
#      12   plt.ylim([0,200])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_mae'

# %%
test_predictions = model.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 250]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

test_errors = abs(test_predictions - test_labels)


print('Mean Absolute Error:', round(np.mean(test_errors), 2))

mape = np.mean(100 * (test_errors / test_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 5.09
# Accuracy: 97.46 %.

# %%
train_predictions = model.predict(normed_train_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(train_labels, train_predictions)
plt.xlabel('True Values [House_Price_Index]')
plt.ylabel('Predictions [House_Price_Index]')
lims = [140, 220]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
train_errors = abs(train_predictions - train_labels)


print('Mean Absolute Error:', round(np.mean(train_errors), 2))

mape = np.mean(100 * (train_errors / train_labels))
accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 3.0
# Accuracy: 98.35 %.

# %%
prediction_features=features   #produce prediction result
prediction_features
# Out:
#      House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0                             204.075072                     5.93
# 1                             206.680701                     5.86
# 2                             209.323123                     5.72
# 3                             212.054408                     5.58
# 4                             213.506930                     5.70
# ..                                   ...                      ...
# 161                           201.556531                     4.55
# 162                           201.165615                     4.63
# 163                           201.119760                     4.83
# 164                           201.226378                     4.87
# 165                           200.791822                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0              46445            18798.114                4.8  1096833.984
# 1              50442            18825.633                4.8  1152815.433
# 2              50442            18825.633                4.7  1152815.433
# 3              50442            18825.633                4.8  1152815.433
# 4              50442            18825.633                4.8  1152815.433
# ..               ...                  ...                ...          ...
# 161            79844            19216.182                3.8  1861147.410
# 162            79844            19216.182                3.8  1861147.410
# 163            79844            19216.182                3.8  1861147.410
# 164            79844            19216.182                3.8  1861147.410
# 165            79844            19216.182                3.9  1861147.410
#
#      Crime_Rate  Median_Debt  New_Structures  Economic_Conditions_Index  \
# 0      673.0543       214701     5852.065587                       2.39
# 1      673.0543       215976     4700.094832                       2.74
# 2      673.0543       215976     4978.336136                       2.65
# 3      673.0543       215976     4541.492838                       2.49
# 4      673.0543       218751     4545.705558                       2.50
# ..          ...          ...             ...                        ...
# 161    541.0310       245242     5090.556959                       2.62
# 162    541.0310       245242     4911.314579                       2.92
# 163    541.0310       244777     6074.946755                       2.96
# 164    541.0310       244777     6341.929028                       2.92
# 165    541.0310       244777     4781.127861                       3.02
#
#      CPI less shelter  Percent_With_Mortgage_Debt  \
# 0             186.900                        32.9
# 1             187.900                        32.9
# 2             188.400                        32.9
# 3             187.600                        32.9
# 4             189.200                        32.7
# ..                ...                         ...
# 161           233.643                        27.8
# 162           234.836                        27.8
# 163           234.245                        27.0
# 164           233.082                        27.0
# 165           231.888                        27.0
#
#      Percent_With_Severely_Delinquent_Debt
# 0                                      0.9
# 1                                      0.8
# 2                                      0.8
# 3                                      0.8
# 4                                      0.9
# ..                                     ...
# 161                                    1.9
# 162                                    1.9
# 163                                    1.9
# 164                                    1.9
# 165                                    1.9
#
# [166 rows x 13 columns]

# %%
prediction_features.pop('House_Price_Index(S&P/Case-Shiller)')
normed_prediction_features=norm(prediction_features)
prediction_result=model.predict(normed_prediction_features)
prediction_result=pd.DataFrame(prediction_result)
rawdataset=raw_dataset.join(prediction_result)
rawdataset
# Out:
#           Date  House_Price_Index(S&P/Case-Shiller)  Mortgage_Rate (30 yers)  \
# 0     3/1/2005                           204.075072                     5.93
# 1     4/1/2005                           206.680701                     5.86
# 2     5/1/2005                           209.323123                     5.72
# 3     6/1/2005                           212.054408                     5.58
# 4     7/1/2005                           213.506930                     5.70
# ..         ...                                  ...                      ...
# 161   8/1/2018                           201.556531                     4.55
# 162   9/1/2018                           201.165615                     4.63
# 163  10/1/2018                           201.119760                     4.83
# 164  11/1/2018                           201.226378                     4.87
# 165  12/1/2018                           200.791822                     4.64
#
#      Personal_Income  Resident_Population  Unemployment_Rate          GDP  \
# 0              46445            18798.114                4.8  1096833.984
# 1              50442            18825.633                4.8  1152815.433
# 2              50442            18825.633                4.7  1152815.433
# 3              50442            18825.633                4.8  1152815.433
# 4              50442            18825.633                4.8  1152815.433
# ..               ...                  ...                ...          ...
# 161            79844            19216.182                3.8  1861147.410
# 162            79844            19216.182                3.8  1861147.410
# 163            79844            19216.182                3.8  1861147.410
# 164            79844            19216.182                3.8  1861147.410
# 165            79844            19216.182                3.9  1861147.410
#
#      Crime_Rate Percent_With_Mortgage_Debt  Median_Debt  \
# 0      673.0543                     32.90%       214701
# 1      673.0543                     32.90%       215976
# 2      673.0543                     32.90%       215976
# 3      673.0543                     32.90%       215976
# 4      673.0543                     32.70%       218751
# ..          ...                        ...          ...
# 161    541.0310                     27.80%       245242
# 162    541.0310                     27.80%       245242
# 163    541.0310                     27.00%       244777
# 164    541.0310                     27.00%       244777
# 165    541.0310                     27.00%       244777
#
#     Percent_With_Severely_Delinquent_Debt  New_Structures  \
# 0                                   0.90%     5852.065587
# 1                                   0.80%     4700.094832
# 2                                   0.80%     4978.336136
# 3                                   0.80%     4541.492838
# 4                                   0.90%     4545.705558
# ..                                    ...             ...
# 161                                 1.90%     5090.556959
# 162                                 1.90%     4911.314579
# 163                                 1.90%     6074.946755
# 164                                 1.90%     6341.929028
# 165                                 1.90%     4781.127861
#
#      Economic_Conditions_Index  CPI less shelter           0
# 0                         2.39           186.900  228.926987
# 1                         2.74           187.900  216.510223
# 2                         2.65           188.400  214.993454
# 3                         2.49           187.600  212.789795
# 4                         2.50           189.200  211.246323
# ..                         ...               ...         ...
# 161                       2.62           233.643  197.826874
# 162                       2.92           234.836  200.320129
# 163                       2.96           234.245  207.274689
# 164                       2.92           233.082  205.496323
# 165                       3.02           231.888  202.457672
#
# [166 rows x 15 columns]

# %%
rawdataset.to_csv('prediction-result.csv',index = False, header=True)
